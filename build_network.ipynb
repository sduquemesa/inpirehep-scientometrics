# %% [markdown]
# # Build Network Data from database

# %% [markdown]
# ###  Imports and setup

# %%
import pandas as pd
import numpy as np
import datetime
from tqdm.notebook import tqdm

# %%
import networkx as nx

# %%
import requests
from requests.exceptions import HTTPError

import json, sys

# %%
import itertools

# %%
import pprint
pp = pprint.PrettyPrinter(indent=4)

# %%
import pymongo
from pymongo import MongoClient
db_client = MongoClient('172.19.31.5', 27017)
db = db_client['inspirehep']   # use db mongo
articles = db['cern']        # use collection

# %% [markdown]
# ##  Clean and Prepare Data

# %% [markdown]
# ### Fetch docs from database

# %%
cursor = articles.find()

# %% [markdown]
# convert db cursor to pandas dataframe (this might take a while...)

# %%
df = pd.DataFrame(list(cursor))

# %% [markdown]
# The number of documents is

# %%
df.shape
# Out:
# (67031, 6)

# %% [markdown]
# and they look like

# %%
df.sample(10)
# Out:
#            _id                                      citations_ids  \
# 5321   1729547                                                NaN
# 22230  1769799                                                NaN
# 42235  1467838                                                 []
# 14344  1694007  [1769945, 1705328, 1800660, 1714713, 1748796, ...
# 39076   900828                                                NaN
# 15794  1702422                                                NaN
# 8974   1281063                                                NaN
# 54599  1364718  [1764575, 1686740, 1497401, 1393059, 1749069, ...
# 43040  1764201                                                NaN
# 27039  1089854                                                NaN
#
#                          created  \
# 5321   2019-04-15T00:00:00+00:00
# 22230  2019-12-11T00:00:00+00:00
# 42235  2016-06-07T00:00:00+00:00
# 14344  2018-09-14T00:00:00+00:00
# 39076  2011-05-22T00:00:00+00:00
# 15794  2018-11-08T00:00:00+00:00
# 8974   2014-02-13T00:00:00+00:00
# 54599  2015-04-27T00:00:00+00:00
# 43040  2019-11-12T00:00:00+00:00
# 27039  2012-02-21T00:00:00+00:00
#
#                                                    links  \
# 5321   {'citations': 'https://inspirehep.net/api/lite...
# 22230  {'bibtex': 'https://inspirehep.net/api/literat...
# 42235  {'bibtex': 'https://inspirehep.net/api/literat...
# 14344  {'bibtex': 'https://inspirehep.net/api/literat...
# 39076  {'citations': 'https://inspirehep.net/api/lite...
# 15794  {'bibtex': 'https://inspirehep.net/api/literat...
# 8974   {'bibtex': 'https://inspirehep.net/api/literat...
# 54599  {'bibtex': 'https://inspirehep.net/api/literat...
# 43040  {'bibtex': 'https://inspirehep.net/api/literat...
# 27039  {'citations': 'https://inspirehep.net/api/lite...
#
#                                                 metadata  \
# 5321   {'citation_count_without_self_citations': 11, ...
# 22230  {'citation_count_without_self_citations': 1, '...
# 42235  {'citation_count_without_self_citations': 0, '...
# 14344  {'collaborations': [{'value': 'ATLAS'}], 'cita...
# 39076  {'citation_count_without_self_citations': 2, '...
# 15794  {'citation_count_without_self_citations': 17, ...
# 8974   {'citation_count_without_self_citations': 17, ...
# 54599  {'citation_count_without_self_citations': 48, ...
# 43040  {'citation_count_without_self_citations': 0, '...
# 27039  {'citation_count_without_self_citations': 25, ...
#
#                                 updated
# 5321   2021-01-09T17:04:31.132996+00:00
# 22230  2020-11-27T03:59:57.994804+00:00
# 42235  2021-01-06T18:57:30.759053+00:00
# 14344  2020-11-27T02:56:48.596468+00:00
# 39076  2020-11-26T20:23:26.224020+00:00
# 15794  2021-01-09T19:04:26.793668+00:00
# 8974   2020-11-26T22:52:31.379904+00:00
# 54599  2021-01-09T12:08:30.616275+00:00
# 43040  2021-01-07T01:03:38.200305+00:00
# 27039  2020-11-26T21:04:55.717528+00:00

# %% [markdown]
# notice that the "numerical" values are of type string...

# %% [markdown]
# ### Docs with no citations

# %% [markdown]
# Now we extract from the dataframe those rows with missing values

# %%
has_NaN = df.isnull().any(axis=1)

# %%
df[has_NaN].sample(5)
# Out:
#            _id citations_ids                    created  \
# 16925  1265470           NaN  2013-11-22T00:00:00+00:00
# 33787   920977           NaN  2011-07-28T00:00:00+00:00
# 30237  1611290           NaN  2017-07-25T00:00:00+00:00
# 60192  1429613           NaN  2016-03-17T00:00:00+00:00
# 39594  1625356           NaN  2017-09-26T00:00:00+00:00
#
#                                                    links  \
# 16925  {'citations': 'https://inspirehep.net/api/lite...
# 33787  {'citations': 'https://inspirehep.net/api/lite...
# 30237  {'bibtex': 'https://inspirehep.net/api/literat...
# 60192  {'bibtex': 'https://inspirehep.net/api/literat...
# 39594  {'bibtex': 'https://inspirehep.net/api/literat...
#
#                                                 metadata  \
# 16925  {'citation_count_without_self_citations': 62, ...
# 33787  {'citation_count_without_self_citations': 2, '...
# 30237  {'citation_count_without_self_citations': 13, ...
# 60192  {'citation_count_without_self_citations': 0, '...
# 39594  {'citation_count_without_self_citations': 0, '...
#
#                                 updated
# 16925  2020-11-26T22:42:50.664315+00:00
# 33787  2021-01-07T05:33:05.796318+00:00
# 30237  2020-11-27T01:58:18.979559+00:00
# 60192  2021-01-16T10:29:44.455734+00:00
# 39594  2020-11-27T02:06:25.826075+00:00

# %% [markdown]
# This `NaN` values are related to the articles that are citing those in the collaboration. To double-check this lets run a count

# %%
def check_collab(metadata_dict):
    if 'collaborations' in metadata_dict.keys():
        return np.any([(collab['value'] in ['ATLAS','CMS','ALICE','LHCb']) for collab in metadata_dict['collaborations']])
    else:
        return 'Not in Collab'

df['metadata'].map( 
    check_collab
).value_counts()
# Out:
# Not in Collab    46610
# True             16595
# False             3826
# Name: metadata, dtype: int64

# %% [markdown]
# here
# - `True` means that the doc is in any of the collaborations (ATLAS, CMS, ALICE, LHCb),
# - `False` that the doc is in a collaboration other than the ones listed above,
# - `Not in Collab`... is quite self explanatory ;)

# %% [markdown]
# Lets replace `NaN` values with an empty list

# %%
df['citations_ids'] = df['citations_ids'].fillna(0).apply(lambda value: [] if value==0 else value)

# %% [markdown]
# ### Unpack values of interest

# %% [markdown]
# Unpack values of interest fro the metadata column and add them to a new column

# %% [markdown]
# #####  title

# %%
df['title'] = df['metadata'].map( 
    lambda metadata_dict: metadata_dict['titles'][0]['title'],
    na_action='ignore'
)

# %% [markdown]
# check for missing values

# %%
df['title'].isnull().any()
# Out:
# False

# %% [markdown]
# #####  document type

# %% [markdown]
# (this is a list because a document can have several document types)

# %%
df['document_type'] = df['metadata'].map( 
    lambda metadata_dict: metadata_dict['document_type'],
    na_action='ignore'
)

# %% [markdown]
# #####  journal info

# %% [markdown]
# First we want to know what are the available keys nested in `publication_info`

# %%
def extract_keys(metadata_dict: dict):
    if ('publication_info' in metadata_dict.keys()): 
        key_list = [publication.keys() for publication in metadata_dict['publication_info']]
        return key_list[0]
    else: 
        return []

journal_info_keys = df['metadata'].map( 
    extract_keys
)

# %%
journal_info_keys.sample(10)
# Out:
# 10308             (cnum, conference_record, parent_record)
# 30326    (artid, journal_record, page_start, year, jour...
# 9924     (artid, journal_record, journal_volume, page_s...
# 260                              (conference_record, cnum)
# 38122    (artid, journal_record, year, journal_issue, j...
# 65918    (artid, journal_record, year, parent_record, c...
# 23983    (artid, journal_issue, page_start, year, journ...
# 39114                                                   []
# 21708                                                   []
# 20071         (artid, journal_title, year, journal_volume)
# Name: metadata, dtype: object

# %% [markdown]
# with the possible keys being

# %%
np.unique(list(itertools.chain.from_iterable(journal_info_keys)))
# Out:
# array(['artid', 'cnum', 'conf_acronym', 'conference_record',
#        'journal_issue', 'journal_record', 'journal_title',
#        'journal_volume', 'material', 'page_end', 'page_start',
#        'parent_isbn', 'parent_record', 'parent_report_number',
#        'pubinfo_freetext', 'year'], dtype='<U20')

# %% [markdown]
# Lets then just check some specific examples to get the feeling...

# %%
journal_info_keys[5]
# Out:
# dict_keys(['conference_record', 'cnum'])

# %%
df['metadata'][5]
# Out:
# {'arxiv_eprints': [{'categories': ['nucl-ex', 'hep-ex'],
#    'value': '2101.03857'}],
#  'author_count': 1,
#  'authors': [{'bai': 'V.Feuillard.1', 'full_name': 'Feuillard, Victor'}],
#  'citation_count': 0,
#  'citation_count_without_self_citations': 0,
#  'collaborations': [{'value': 'ALICE'}],
#  'control_number': 1840193,
#  'document_type': ['conference paper'],
#  'inspire_categories': [{'source': 'arxiv', 'term': 'Experiment-Nucl'},
#   {'source': 'arxiv', 'term': 'Experiment-HEP'}],
#  'preprint_date': '2021-01-11',
#  'publication_info': [{'cnum': 'C20-07-07',
#    'conference_record': {'ref': 'https://inspirehep.net/api/conferences/1778269'}}],
#  'referenced_authors_bais': ['A.Abrahantes.Quintana.1',
#   'A.Abramyan.2',
#   'A.A.Capon.2',
#   'A.Adare.1',
#   'A.Adler.2',
#   'A.Agostinelli.1',
#   'A.Ahmad.Masoodi.2',
#   'A.A.Ivanov.1',
#   'A.Alfonso.Albero.1',
#   'A.Alkin.1',
#   'A.Andronic.3',
#   'A.Anzo.1',
#   'A.A.P.Suaide.1',
#   'A.Arefiev.1',
#   'A.Arend.1',
#   'A.Argentieri.1',
#   'A.Asryan.1',
#   'A.Augustinus.1',
#   'A.A.Vinogradov.1',
#   'A.Badala.1',
#   'A.Balbino.1',
#   'A.Baldisseri.1',
#   'A.Baldit.1',
#   'A.Baranov.1',
#   'A.Batista.Camejo.2',
#   'A.Battig.1',
#   'A.Bay.4',
#   'A.Beiter.1',
#   'A.Bell.Hechavarria.1',
#   'A.Belogianni.1',
#   'A.Benato.1',
#   'A.Bercuci.1',
#   'A.Berdnikova.1',
#   'A.Bertolin.1',
#   'A.Bhasin.1',
#   'A.Bianchi.1',
#   'A.Bilandzic.1',
#   'A.Bizzeti.1',
#   'A.B.Kaidalov.1',
#   'A.B.Kurepin.1',
#   'A.Blanc.2',
#   'A.B.Morris.1',
#   'A.Bogdanov.1',
#   'A.Bondar.1',
#   'A.Borissov.1',
#   'A.Braem.2',
#   'A.B.Rodrigues.1',
#   'A.Brossa.Gonzalo.1',
#   'A.Buonaura.1',
#   'A.Bursche.1',
#   'A.Camboni.1',
#   'A.Casanova.Diaz.1',
#   'A.C.Crocombe.1',
#   'A.C.Davis.2',
#   'A.C.dos.Reis.1',
#   'A.Charpy.1',
#   'A.Chauvin.1',
#   'A.Chubykin.2',
#   'A.C.Oliveira.da.silva.1',
#   'A.Colla.4',
#   'A.Collu.2',
#   'A.Comerma.2',
#   'A.Contu.2',
#   'A.Dainese.2',
#   'Adam.Wegrzynek.1',
#   'A.Danilina.1',
#   'A.Danu.1',
#   'A.Dashi.1',
#   'A.De.Azevedo.Moregula.1',
#   'A.De.Caro.1',
#   'A.De.Falco.1',
#   'A.Deisting.1',
#   'A.Deloff.1',
#   'A.Dendek.1',
#   'A.Deppman.1',
#   'A.Deppman.2',
#   'A.Devaux.1',
#   'A.Di.Bartelomen.1',
#   'A.Di.Canto.1',
#   'A.Di.Mauro.1',
#   'A.Diozcora.Vargas.Trevino.1',
#   'A.D.L.Bell.Hechavarria.1',
#   'A.Dosil.su.rez.6',
#   'A.Dubla.1',
#   'A.Dziurda.1',
#   'A.Dzyuba.2',
#   'A.E.Dubey.1',
#   'A.Ene.1',
#   'A.Enokizono.1',
#   'A.E.Ohlson.1',
#   'A.Erokhin.3',
#   'A.Evangelista.1',
#   'A.Falabella.1',
#   'A.Fantoni.1',
#   'A.F.Dobrin.1',
#   'A.Feliciello.1',
#   'A.Fernandez.Prieto.1',
#   'A.Fernandez.Tellez.1',
#   'A.Ferrero.3',
#   'A.Ferretti.1',
#   'A.Festanti.1',
#   'A.F.Mechler.1',
#   'A.F.Nassirpour.1',
#   'A.Francescon.1',
#   'A.Francisco.1',
#   'A.Franco.1',
#   'A.Furs.2',
#   'A.Gabrielli.2',
#   'A.G.Agocs.1',
#   'A.Gallas.1',
#   'A.Gallas.Torreira.2',
#   'A.Garcia.Lopez.1',
#   'A.Garibli.1',
#   'A.G.Fedunov.1',
#   'A.Gheata.2',
#   'A.G.Knospe.1',
#   'A.Golutvin.1',
#   'A.Gomes.1',
#   'A.Gomez.ramirez.2',
#   'A.Goswami.4',
#   'A.Grecu.1',
#   'A.Grelli.1',
#   'A.Grigoras.1',
#   'A.Grigoryan.1',
#   'A.Guichard.1',
#   'A.Gupta.10',
#   'A.Gupta.7',
#   'A.Guth.2',
#   'A.Hansen.1',
#   'A.Harlenderova.1',
#   'A.Harton.1',
#   'A.Harutyunyan.1',
#   'A.Hayrapetyan.1',
#   'A.Heister.1',
#   'A.Herghelegiu.1',
#   'A.Hicheur.1',
#   'A.H.J.Chauvin.1',
#   'A.Hornung.2',
#   'A.H.Rezaeian.1',
#   'A.Hurtado.1',
#   'A.I.Pavlinov.1',
#   'A.Isakov.2',
#   'A.I.Sheikh.1',
#   'A.Ivanov.4',
#   'A.Jacholkowski.1',
#   'A.Jawahery.1',
#   'Ajay.Kumar.2',
#   'Ajay.Kumar.Dash.1',
#   'A.J.Castro.5',
#   'A.J.Rubio.Montero.1',
#   'A.J.Turvey.4',
#   'A.Junique.1',
#   'A.Jusko.1',
#   'A.Kamal.2',
#   'A.Karasu.Uysal.2',
#   'A.K.Bhati.2',
#   'A.K.Dubey.2',
#   'A.K.Duggal.1',
#   'A.K.Dutta.Majumdar.1',
#   'A.Khanzadeev.1',
#   'A.Khatun.1',
#   'A.Khuntia.1',
#   'A.Kisiel.1',
#   'A.K.Kuonen.1',
#   'A.Klimov.2',
#   'A.Klovning.1',
#   'A.Kluge.1',
#   'A.Kolojvari.1',
#   'A.Kondratyev.1',
#   'A.Konevskikh.1',
#   'A.Kravcakova.1',
#   'A.Kugler.1',
#   'A.Kuryakin.1',
#   'A.Kusina.1',
#   'A.Lai.2',
#   'A.Lardeux.2',
#   'A.Lattuca.1',
#   'Alberto.Caliva.1',
#   'A.Leflat.1',
#   'Aleksandr.Petrov.1',
#   'Alessandro.Cardini.1',
#   'Alessio.Sarti.1',
#   'Alexander.Akindinov.1',
#   'Alexander.Artamonov.1',
#   'Alexander.I.Bolozdynya.1',
#   'Alexander.I.Zinchenko.1',
#   'Alex.Birnkraut.1',
#   'Alexey.Makarov.1',
#   'Alfredo.Musso.1',
#   'A.Lindner.4',
#   'A.Liu.1',
#   'A.Loi.3',
#   'A.Lowe.1',
#   'A.Lupato.1',
#   'A.Lusiani.1',
#   'A.Maevskaya.1',
#   'A.Mairani.1',
#   'A.Maire.2',
#   'A.Malinin.1',
#   'Amal.Sarkar.1',
#   'A.Mamonov.1',
#   'A.Marcel.2',
#   'Amaresh.Jaiswal.1',
#   'A.Margotti.1',
#   'A.Marin.5',
#   'A.Martinez.Davalos.1',
#   'A.Martinez.davalos.2',
#   'A.Marzari.chiesa.2',
#   'A.Mas.4',
#   'A.Masoni.1',
#   'A.Massafferri.Rodrigues.1',
#   'A.Mastroserio.1',
#   'A.Mathad.1',
#   'A.Matyja.1',
#   'A.Mazurov.1',
#   'A.Mazzoni.1',
#   'A.M.Barbano.1',
#   'A.M.C.Glaenzer.1',
#   'A.Mcnab.1',
#   'A.Menchaca.Rocha.1',
#   'A.Merli.2',
#   'A.M.Frolov.1',
#   'A.M.Gago.1',
#   'A.Michalon.1',
#   'A.Mischke.1',
#   'A.Mishra.3',
#   'A.M.Khan.3',
#   'A.M.Kubera.1',
#   'A.M.Mathis.1',
#   'A.Modak.3',
#   'A.Modden.1',
#   'A.Mogini.1',
#   'A.Mohanty.2',
#   'A.Morreale.1',
#   'A.Morsch.1',
#   'A.Mulliri.2',
#   'A.M.Veen.1',
#   'A.M.Whitehead.1',
#   'A.Nandi.4',
#   'A.Narayan.2',
#   'A.N.Dovbnya.1',
#   'Andrea.Alici.1',
#   'Andrea.Mauri.2',
#   'Andrea.Rossi.1',
#   'Andreas.Schopper.1',
#   'Andres.Sandoval.1',
#   'Andrey.Vasiliev.1',
#   'A.Neagu.3',
#   'A.Nedosekin.1',
#   'A.N.Flores.1',
#   'Angelo.Carbone.1',
#   'Angelo.Rivetti.1',
#   'A.Nianine.1',
#   'Anita.Mahajan.1',
#   'Anjali.Sharma.1',
#   'Ankita.Sharma.1',
#   'A.N.Kurepin.1',
#   'A.Nogay.1',
#   'Antonio.Augusto.Alves.1',
#   'A.Nyatha.1',
#   'A.Nyiri.1',
#   'A.N.Zubarev.1',
#   'A.Oblakowska.Mucha.1',
#   'A.Ochirov.1',
#   'A.Okatan.1',
#   'A.Ortiz.Velasquez.2',
#   'A.Ortiz.Velazquez.1',
#   'A.Oskarsson.1',
#   'A.Ossowska.1',
#   'A.Oyanguren.1',
#   'A.Palaha.1',
#   'A.Palano.1',
#   'A.Palmeri.1',
#   'A.Pantaleo.1',
#   'A.Papanestis.1',
#   'A.Passfeld.1',
#   'A.Pastore.2',
#   'A.P.de.Haas.1',
#   'A.Pearce.2',
#   'A.Pellegrino.1',
#   'A.Pepato.1',
#   'A.Pesci.1',
#   'A.Peters.2',
#   'A.Petridis.1',
#   'A.Petrolini.1',
#   'A.Piccotti.1',
#   'A.Piucci.2',
#   'A.P.Kalweit.1',
#   'A.Poluektov.1',
#   'A.Pop.2',
#   'A.Pop.4',
#   'A.Popov.14',
#   'A.P.Rollings.1',
#   'A.Przybyla.1',
#   'A.Puig.Navarro.1',
#   'A.Pulvirenti.1',
#   'A.Punin.1',
#   'A.Rachevski.1',
#   'A.Rademakers.1',
#   'A.Radu.2',
#   'A.Rakotozafindrabe.1',
#   'A.Ramirez.Reyes.1',
#   'A.Reshetin.1',
#   'A.Riabov.1',
#   'A.R.Liu.1',
#   'A.Robert.2',
#   'A.Rodriguez.manso.2',
#   'A.Romero.Vidal.1',
#   'A.Rosano.2',
#   'A.Rotondi.1',
#   'A.Roy.8',
#   'A.R.Redelbach.1',
#   'A.R.Reolon.1',
#   'A.R.Schmier.1',
#   'A.R.Timmins.1',
#   'A.Rubio.1',
#   'A.Rustamov.1',
#   'A.Rybicki.1',
#   'A.Sanchez.Gonzalez.1',
#   'A.Sasikumar.Menon.1',
#   'A.Satta.1',
#   'A.Schmah.1',
#   'A.Sciubba.1',
#   'A.Semennikov.1',
#   'A.Sergi.1',
#   'A.Seuthe.1',
#   'A.Sevcenco.1',
#   'A.Shabanov.1',
#   'A.Shabetai.1',
#   'A.Shangaraev.1',
#   'Ashfaq.Ahmad.1',
#   'A.Shurygin.1',
#   'Ashutosh.Kumar.Pandey.1',
#   'A.Silenzi.1',
#   'A.S.Nyanin.1',
#   'A.Soldatov.1',
#   'A.Soloviev.1',
#   'A.Songmoolnak.1',
#   'A.Stavinskiy.1',
#   'A.Stocchi.2',
#   'A.S.Vodopyanov.1',
#   'A.Szabelski.2',
#   'A.Szabo.1',
#   'A.Szanto.de.Toledo.1',
#   'A.Szczepankiewicz.1',
#   'A.Szostak.1',
#   'A.Tarantola.peloni.1',
#   'A.Tarazona.martinez.2',
#   'A.Tauro.2',
#   'A.Tayduganov.1',
#   'A.Telesca.1',
#   'A.Ter.Minasyan.1',
#   'A.Tikhonov.2',
#   'A.Toia.1',
#   'A.Tournaire.1',
#   'A.Trifiro.1',
#   'A.Trisovic.1',
#   'A.Tsaregorodtsev.1',
#   'A.Tsvetkov.1',
#   'A.Tully.1',
#   'A.Tumkin.1',
#   'A.Ukleja.1',
#   'A.Uras.1',
#   'A.U.Rehman.1',
#   'A.Usachov.2',
#   'A.Ustyuzhanin.1',
#   'A.Utrobicic.1',
#   'A.Vacchi.1',
#   'A.Vagner.2',
#   'A.Valassi.1',
#   'A.van.den.Brink.1',
#   'A.Vascotto.1',
#   'A.Vauthier.1',
#   'A.V.Berezhnoy.1',
#   'A.V.Efremov.1',
#   'A.Velure.1',
#   'A.Venkateswaran.1',
#   'A.Villatoro.Tello.1',
#   'A.Vitkovskiy.1',
#   'A.V.Kazantsev.1',
#   'A.Vollhardt.1',
#   'A.Vorobyev.2',
#   'A.Vyushin.1',
#   'A.Weiden.1',
#   'A.Wiesenacker.1',
#   'A.Wilk.1',
#   'A.W.J.Gal.1',
#   'A.W.Rauf.1',
#   'A.Xu.3',
#   'A.Yuncu.1',
#   'A.Zalite.1',
#   'A.Zaman.1',
#   'A.Zarochentsev.1',
#   'A.Zenin.2',
#   'A.Zepeda.1',
#   'A.Zhelezov.1',
#   'A.Zichichi.1',
#   'A.Zimmermann.1',
#   'A.Zucchini.1',
#   'B.Adeva.1',
#   'B.A.Hess.1',
#   'Baidyanath.Sahoo.1',
#   'B.Alessandro.1',
#   'B.Ali.2',
#   'B.A.Trzeciak.1',
#   'B.Audurier.1',
#   'B.Audurier.2',
#   'B.Bathen.1',
#   'B.Batsukh.1',
#   'B.Becker.1',
#   'B.Bhattacharjee.2',
#   'B.Boyer.1',
#   'B.Cheynis.1',
#   'B.Couturier.1',
#   'B.Delaney.1',
#   'B.Di.Ruzza.1',
#   'B.Doenigus.1',
#   'B.Donigus.1',
#   'B.Ducloue.1',
#   'B.Ducloue.2',
#   'Beom.Su.Chang.1',
#   'B.Erazmus.1',
#   'B.Espagnon.1',
#   'B.Garcia.Plana.1',
#   'B.Ghidini.1',
#   'B.G.Siddi.1',
#   'B.Guerzoni.1',
#   'B.Guiot.1',
#   'B.Hamilton.2',
#   'B.Hicks.1',
#   'B.Hippolyte.1',
#   'B.H.Lim.2',
#   'B.Hohlweger.1',
#   'B.I.Abelev.1',
#   'Bikash.Sinha.1',
#   'Biplab.Dey.1',
#   'B.Jost.1',
#   'B.Ketzer.1',
#   'B.Khanji.1',
#   'B.Kileng.1',
#   'B.Kim.3',
#   'B.K.Kim.1',
#   'B.K.Nandi.1',
#   'B.Leverington.1',
#   'B.Lim.2',
#   'B.Malecki.2',
#   'B.Maurin.1',
#   'B.Mayer.1',
#   'B.Mohanty.1',
#   'B.Naik.1',
#   'B.Pastircak.1',
#   'B.Paul.5',
#   'B.Pietrzyk.1',
#   'B.Pini.1',
#   'B.Polichtchouk.1',
#   'B.Polishchuk.1',
#   'B.Pommeresch.2',
#   'B.Quintana.2',
#   'B.Rachwal.1',
#   'B.R.Gruberg.Cazon.1',
#   'B.Rumyantsev.1',
#   'B.Sahlmueller.1',
#   'B.Saitta.1',
#   'B.Sanmartin.Sedes.1',
#   'B.Schackert.1',
#   'B.Schaefer.1',
#   'B.Schenke.1',
#   'B.Schmidt.1',
#   'B.Sciascia.1',
#   'B.Singh.4',
#   'B.Sitar.1',
#   'B.Skaali.1',
#   'B.S.Nielsen.1',
#   'B.S.Nilsen.1',
#   'B.Souza.de.Paula.1',
#   'B.Spaan.1',
#   'B.Srivastava.1',
#   'B.Storaci.1',
#   'B.S.Windelband.1',
#   'B.Teyssier.1',
#   'B.T.Meadows.1',
#   'B.T.Rascanu.1',
#   'B.V.Batyunya.1',
#   'B.V.Grinyov.2',
#   'B.V.Haller.2',
#   'B.V.Jacak.1',
#   'B.V.K.S.Potukuchi.1',
#   'B.Volkel.1',
#   'B.Voneki.1',
#   'B.Vulpescu.1',
#   'B.V.Zagreev.1',
#   'B.Wagner.1',
#   'B.W.Zhang.1',
#   'B.Yun.Ky.1',
#   'B.Yuting.1',
#   'B.Z.Kopeliovich.1',
#   'C.A.Aidala.1',
#   'C.Abellan.2',
#   'C.Adler.1',
#   'C.A.Loizides.1',
#   'C.Alves.Garcia.Prado.1',
#   'Camila.De.Conti.1',
#   'C.Andrei.1',
#   'C.Anson.1',
#   'C.A.Pruneau.1',
#   'Carlos.Albert.Salgado.1',
#   'C.Bartels.2',
#   'C.Baumann.1',
#   'C.Beattie.2',
#   'C.Bedda.1',
#   'C.Bergmann.1',
#   'C.Betancourt.1',
#   'C.Bianchin.1',
#   'C.Blume.1',
#   'C.Bombonati.1',
#   'C.Bortolin.1',
#   'C.Bourjau.1',
#   'C.Bozzi.1',
#   'C.Burr.1',
#   'C.Cavicchioli.1',
#   'C.Ceballos.sanchez.2',
#   'C.Cheshkov.1',
#   'C.Cicalo.1',
#   'C.Cirstoiu.1',
#   'C.C.Kuhn.1',
#   'C.Colledani.1',
#   'C.Combaret.1',
#   'C.D.Ambrosio.1',
#   'C.Dell.Olio.1',
#   'C.De.Martin.1',
#   'C.Deplano.1',
#   'C.Di.Giglio.1',
#   'C.Dinca.1',
#   'C.Duarte.Galvan.1',
#   'C.Engster.1',
#   'C.E.Perez.Lara.1',
#   'C.Farber.1',
#   'C.Finck.1',
#   'C.Fitzpatrick.1',
#   'C.Frei.1',
#   'C.Furget.1',
#   'C.Garabatos.2',
#   'C.Gargiulo.1',
#   'C.Gaspar.2',
#   'C.Geuna.1',
#   'C.G.Ivan.1',
#   'C.Gobel.Burlamaqui.de.Mello.1',
#   'C.Gonzalez.Gutierrez.1',
#   'C.Gotti.1',
#   'C.Gregory.1',
#   'C.Grigoras.1',
#   'C.Grigoryan.1',
#   'C.Gu.2',
#   'C.Guarnaccia.1',
#   'C.Guerra.Gutierrez.1',
#   'C.G.Yaldo.2',
#   'C.Hadjidakis.1',
#   'C.Hadjivasiliou.2',
#   'C.Haen.2',
#   'Changzhou.Xiang.1',
#   'Chao.Song.Gao.1',
#   'C.Hasse.1',
#   'C.H.Christensen.1',
#   'Chen.Chen.2',
#   'Chiara.Pinto.1',
#   'C.Hills.1',
#   'C.H.Murphy.1',
#   'Christelle.Sophie.Roy.1',
#   'C.H.Stokkevag.1',
#   'C.Hughes.2',
#   'C.Hu.Guo.1',
#   'Chunhui.Zhang.1',
#   'Cindy.Mordasini.1',
#   'C.Insa.1',
#   'C.Ionita.1',
#   'C.Jahnke.1',
#   'C.Jena.1',
#   'C.J.G.Onderwater.1',
#   'C.J.Myers.1',
#   'C.Jones.1',
#   'C.Joram.1',
#   'C.J.Oskamp.1',
#   'C.J.Schmidt.1',
#   'C.Khurewathanakul.1',
#   'C.K.Jorgensen.1',
#   'C.Klein.3',
#   'C.Klein.Boesing.1',
#   'C.Kobdaj.1',
#   'C.Kottachchi.Kankanamge.Don.1',
#   'C.Kouzinopoulos.1',
#   'C.Lagana.1',
#   'C.Langenbruch.1',
#   'C.Lara.1',
#   'Clare.Bernard.1',
#   'C.Lazzeroni.1',
#   'C.L.Da.Silva.1',
#   'C.Le.Gailliard.1',
#   'C.L.Huang.1',
#   'C.Lippmann.1',
#   'C.L.Ristea.1',
#   'C.Luzzi.1',
#   'C.Magureanu.1',
#   'C.Manea.1',
#   'C.Marin.benito.1',
#   'C.Markert.1',
#   'C.Marzocca.1',
#   'C.Matteuzzi.1',
#   'C.Mayer.2',
#   'C.M.Costa.Sobral.1',
#   'C.Meaux.2',
#   'C.Mengke.1',
#   'C.Mitu.1',
#   'C.Nattrass.1',
#   'C.Nguyen.Mau.3',
#   'C.Nygaard.1',
#   'C.Oppedisano.1',
#   'C.Pajares.1',
#   'C.Parkes.1',
#   'C.Pastore.1',
#   'C.Patrignani.1',
#   'C.Perez.2',
#   'C.Petta.1',
#   'C.Piemonte.1',
#   'C.Potterat.1',
#   'C.Prouve.1',
#   'C.Reichling.1',
#   'C.Remon.Alepuz.1',
#   'C.Renard.2',
#   'C.Sanchez.Gras.1',
#   'C.Sanchez.Mayordomo.1',
#   'C.Santamarina.Rios.1',
#   'C.Satriano.1',
#   'C.Schiaua.1',
#   'C.Silvestre.2',
#   'C.S.Lo.2',
#   'C.Sogaard.1',
#   'C.Soncco.Meza.1',
#   'C.Soos.1',
#   'C.Suire.1',
#   'C.Tagridis.1',
#   'C.T.Dean.1',
#   'C.Terrevoli.1',
#   'C.Torcato.de.Matos.1',
#   'C.Vazquez.Sierra.1',
#   'C.Wabnitz.1',
#   'C.Weisser.1',
#   'C.W.Fabjan.2',
#   'C.Williams.3',
#   'C.Xu.19',
#   'C.Yang.12',
#   'C.Zach.2',
#   'C.Zampolli.1',
#   'C.Zhao.1',
#   'D.Adamova.1',
#   'Dai.Cui.Zhou.1',
#   'D.Aleksandrov.1',
#   'D.Alexandre.2',
#   'D.A.Milanes.1',
#   'D.A.Moreira.De.Godoy.1',
#   'D.Andreou.2',
#   'D.Antonczyk.1',
#   'D.Banerjee.7',
#   'D.Bartos.1',
#   'D.Bauri.1',
#   'D.Berenyi.1',
#   'D.Berninghoff.2',
#   'D.Berzano.1',
#   'D.Blau.1',
#   'D.Bobulska.1',
#   'D.Bonnet.1',
#   'D.B.Piyarathna.3',
#   'D.B.Rana.1',
#   'D.Brundu.2',
#   'D.Bucher.1',
#   'D.Budnikov.1',
#   'D.Caffarri.1',
#   'D.Campora.Perez.1',
#   'D.Cavazza.1',
#   'D.C.Craik.1',
#   'D.Chamont.1',
#   'D.Charrier.1',
#   'D.C.Miskowiec.1',
#   'D.Colella.1',
#   'D.C.Vernekohl.1',
#   'D.Dabrowski.2',
#   'D.Decamp.1',
#   'D.De.Gruttola.1',
#   'D.Dell.Olio.1',
#   'D.Derkach.1',
#   'D.de.Vaux.1',
#   'D.Devetak.1',
#   'D.Di.Bari.1',
#   'D.Dobrigkeit.Chinellato.1',
#   'D.Domenicis.gimenez.1',
#   'Debasish.Das.1',
#   'Debojit.Sarkar.1',
#   'Deepanwita.Dutta.1',
#   'Deepa.Thomas.1',
#   'D.E.Hutchcroft.1',
#   'D.Elia.1',
#   'D.Emschermann.1',
#   'D.Eschweiler.1',
#   'D.Evans.1',
#   'Dezso.Varga.1',
#   'D.Fabris.1',
#   'D.Falchieri.1',
#   'D.Fazzini.1',
#   'D.Fehlker.1',
#   'D.Felea.1',
#   'D.Finogeev.1',
#   'D.Flierl.1',
#   'D.F.Lodato.1',
#   'D.Fraissard.1',
#   'D.F.Weiser.1',
#   'D.Galli.1',
#   'D.Gascon.2',
#   'D.G.d.Enterria.1',
#   'D.Gerick.2',
#   'D.Gerstel.2',
#   'D.Golubkov.1',
#   'D.Gottschalk.1',
#   'D.Hasch.1',
#   'D.Hasegan.1',
#   'D.Hatzifotiadou.1',
#   'D.Hill.1',
#   'D.Horak.1',
#   'D.Hynds.2',
#   'Diego.Martinez.Santos.1',
#   'D.I.Patalakha.2',
#   'Dirk.Hutter.1',
#   'D.Jang.3',
#   'D.J.Kim.1',
#   'D.J.Kim.3',
#   'D.Johnson.1',
#   'D.J.Tapia.Takaki.2',
#   'D.Karatovic.1',
#   'D.Kikola.1',
#   'D.Kim.2',
#   'D.Kim.3',
#   'D.Krumbhorn.1',
#   'D.Lacarrere.1',
#   'D.Lancierini.1',
#   'D.L.Keijdener.2',
#   'D.L.Mihaylov.1',
#   'D.Loh.1',
#   'D.Lohner.1',
#   'D.Lucchesi.1',
#   'D.Maisuzenko.2',
#   'D.Mal.kevich.1',
#   'D.Mallick.3',
#   'D.Maniero.1',
#   'D.Marangotto.1',
#   'D.Marras.1',
#   'D.Mayani.1',
#   'D.Melnychuk.1',
#   'D.M.Gomez.Coral.1',
#   'D.M.Madagodahettige.Don.1',
#   'D.M.Muhlheim.2',
#   'D.Moisa.1',
#   'D.Mura.1',
#   'D.Murray.4',
#   'D.M.Websdale.1',
#   'D.Nesterov.2',
#   'D.Nouais.1',
#   'Dominik.Muller.1',
#   'Dong.Wang.1',
#   'Dong.Xiao.1',
#   'D.Pagano.1',
#   'D.Pant.1',
#   'D.Pereima.1',
#   'D.Peresunko.1',
#   'D.Perini.5',
#   'D.Perrino.1',
#   'D.Pinci.1',
#   'D.Pistone.1',
#   'D.P.Johnson.2',
#   'D.P.Mahapatra.1',
#   'D.P.O.Hanlon.1',
#   'D.Popov.1',
#   'D.Rathee.1',
#   'D.R.Gangadharan.1',
#   'D.Roehrich.1',
#   'D.Rohr.2',
#   'D.Roy.4',
#   'D.R.Ward.1',
#   'D.Sakata.1',
#   'D.Savrina.1',
#   'D.Sekihata.1',
#   'D.Serebryakov.1',
#   'D.S.Hwang.1',
#   'D.Silva.De.Albuquerque.1',
#   'D.Silvermyr.1',
#   'D.S.Mitzel.1',
#   'D.Soyk.1',
#   'D.Stocco.1',
#   'D.Swoboda.1',
#   'D.Tapia.Takaki.1',
#   'D.Thakur.1',
#   'D.T.Larsen.1',
#   'D.Tlusty.1',
#   'D.Tonelli.1',
#   'D.Truesdale.1',
#   'D.U.Dixit.1',
#   'D.Vieira.1',
#   'D.Vom.Bruch.2',
#   'D.Voscek.1',
#   'D.Vranic.1',
#   'D.Watanabe.1',
#   'D.W.Kim.2',
#   'D.Y.Tou.1',
#   'D.Zhang.24',
#   'E.Almaraz.Avina.1',
#   'E.A.Meleshko.1',
#   'E.A.R.Casula.1',
#   'E.Aslanides.1',
#   'E.Bartsch.1',
#   'E.Belmont.Moreno.1',
#   'E.Ben.Haim.1',
#   'E.Berdermann.1',
#   'E.Bertholet.1',
#   'E.Biolcati.1',
#   'E.Botta.1',
#   'E.Brucken.1',
#   'E.Bruna.1',
#   'E.Calvo.Villar.1',
#   'E.Cattaruzza.1',
#   'E.Chiavassa.1',
#   'E.Cogneras.1',
#   'E.Crescio.1',
#   'E.Cuautle.1',
#   'E.Dallocco.1',
#   'E.Del.Castillo.Sanchez.4',
#   'E.Denes.1',
#   'E.D.Lesser.1',
#   'E.Dominguez.Rosas.1',
#   'E.Dumonteil.1',
#   'E.Endress.1',
#   'E.Epple.1',
#   'E.E.Sepulveda.1',
#   'E.E.Zabrodin.1',
#   'E.F.Gauger.1',
#   'E.Filoni.1',
#   'E.Fragiacomo.1',
#   'E.Gandolfi.1',
#   'E.G.Ferreiro.2',
#   'E.G.Floratos.1',
#   'E.Gladysz.Dziadus.1',
#   'E.Gonzalez.Hernandez.1',
#   'E.Grauges.1',
#   'E.Gushchin.1',
#   'E.Hellbar.1',
#   'E.H.Olsen.1',
#   'E.H.O.Pohjoisaho.1',
#   'E.Ionescu.1',
#   'E.Jans.2',
#   'E.J.Garcia.Solis.1',
#   'E.J.Millard.1',
#   'E.J.Willsher.1',
#   'E.Kang.1',
#   'E.Kang.2',
#   'E.Karpechev.1',
#   'E.Khairullin.1',
#   'E.K.Koshurnikov.1',
#   'E.Kondratyuk.1',
#   'E.Kornas.1',
#   'E.Kryshen.1',
#   'E.Laudi.2',
#   'Elena.Graverini.1',
#   'E.Leogrande.3',
#   'E.Levin.1',
#   'E.Lopez.Torres.1',
#   'Eluned.Smith.1',
#   'E.Luppi.1',
#   'E.Masson.1',
#   'E.Maurice.1',
#   'E.Meninno.2',
#   'E.M.Fiore.2',
#   'E.M.Gersabeck.1',
#   'E.Michielin.1',
#   'Emma.Buchanan.1',
#   'E.Montes.1',
#   'E.Mudnic.1',
#   'E.Nappi.1',
#   'E.N.Umaka.1',
#   'E.P.D.O.Filho.1',
#   'E.Perez.Lezama.1',
#   'E.P.M.Gabriel.1',
#   'E.Polycarpo.1',
#   'E.Price.2',
#   'E.P.Rogochaya.1',
#   'E.Quercigh.1',
#   'Eric.Thomas.1',
#   'Eric.van.Herwijnen.1',
#   'E.Rindel.1',
#   'E.Rocco.1',
#   'E.Rodrigues.1',
#   'E.Ryabinkin.1',
#   'E.Santovetti.1',
#   'E.Scapparone.1',
#   'E.Schyns.1',
#   'E.Scomparin.1',
#   'E.Serradilla.1',
#   'E.Sharkov.1',
#   'E.Shmanin.1',
#   'E.Siddi.1',
#   'E.Simili.1',
#   'E.S.Martynov.1',
#   'E.Spadaro.Norella.1',
#   'E.Spiriti.1',
#   'E.Stan.2',
#   'E.Stenlund.1',
#   'E.Tournefier.2',
#   'E.Tsilis.1',
#   'E.Ugolini.1',
#   'Eun.Joo.Kim.1',
#   'Eva.Sicking.1',
#   'E.Vercellin.1',
#   'E.Wang.4',
#   'E.Widmann.1',
#   'E.Willsher.1',
#   'Fabio.Catalano.1',
#   'Fabio.Ferrari.1',
#   'Fabrizio.Grosa.1',
#   'F.Agnese.1',
#   'F.Alessio.1',
#   'F.Antinori.1',
#   'F.Archilli.1',
#   'F.Arleo.1',
#   'F.Baltasar.Dos.Santos.Pedrosa.1',
#   'F.Barile.1',
#   'F.Baruffaldi.2',
#   'F.Baryshnikov.2',
#   'F.Bedeschi.1',
#   'F.Benotto.1',
#   'F.Betti.1',
#   'F.Blanc.1',
#   'F.Bock.1',
#   'F.Borotto.1',
#   'F.Bossu.1',
#   'F.Calaon.1',
#   'F.Carena.1',
#   'F.Carena.3',
#   'F.Carminati.1',
#   'F.Carnesecchi.1',
#   'F.Cindolo.1',
#   'F.Coccetti.1',
#   'F.Colamaria.1',
#   'F.Corsi.1',
#   'F.da.Cunha.Marinho.1',
#   'F.De.Moraes.Canedo.1',
#   'F.Desse.1',
#   'F.Dettori.1',
#   'F.Dordei.2',
#   'F.Dumitrache.1',
#   'Federico.Redi.1',
#   'Feng.Chu.Zhou.1',
#   'F.Erhardt.1',
#   'Fernando.Blanco.1',
#   'F.Fan.2',
#   'F.F.Guber.1',
#   'F.Fichera.1',
#   'F.Fleuret.1',
#   'F.Flor.1',
#   'F.Fontanelli.1',
#   'F.Formenti.1',
#   'F.Furano.1',
#   'F.F.Valiev.1',
#   'F.F.Wilson.1',
#   'F.Guerin.1',
#   'F.Herrmann.3',
#   'Filippo.Costa.1',
#   'F.Jiang.2',
#   'F.J.Kress.1',
#   'F.Jonas.1',
#   'F.Jouve.1',
#   'F.J.P.Soler.1',
#   'F.J.Sanchez.rodriguez.1',
#   'F.Keizer.2',
#   'F.Kramer.1',
#   'F.Krizek.1',
#   'F.Lackner.1',
#   'F.Lefevre.1',
#   'F.Lehas.1',
#   'F.Lemaitre.1',
#   'F.L.Ferreira.Rodrigues.1',
#   'F.Librizzi.1',
#   'F.Lionetto.1',
#   'F.Littel.1',
#   'F.Machefert.1',
#   'F.Maciuc.1',
#   'F.Manso.2',
#   'F.Manso.3',
#   'F.Martinez.Vidal.1',
#   'F.Massera.1',
#   'F.Mazzaschi.1',
#   'F.Meddi.1',
#   'F.M.Fionda.1',
#   'F.Minafra.1',
#   'F.Muheim.1',
#   'F.Navach.1',
#   ...],
#  'references': [{'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[1] T. Roser, Nuclear Physics A 698 (1) (2002) 23 – 28.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/584053'},
#    'reference': {'authors': [{'full_name': 'Roser, T.'}],
#     'label': '1',
#     'publication_info': {'journal_title': 'Nucl.Phys.A',
#      'journal_volume': '698',
#      'page_end': '28',
#      'page_start': '23',
#      'year': 2002}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[2] L. Evans P. Bryant, JINST 3 (2008) S08001.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/796247'},
#    'reference': {'authors': [{'full_name': 'Bryant'},
#      {'full_name': 'P., L. Evans'}],
#     'label': '2',
#     'publication_info': {'artid': 'S08001',
#      'journal_title': 'JINST',
#      'journal_volume': '3',
#      'year': 2008}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[3] K. Aamodt et al. (ALICE), Phys. Lett. B696 (2011) 328–337.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/881884'},
#    'reference': {'authors': [{'full_name': 'Aamodt, K.'}],
#     'label': '3',
#     'misc': ['(ALICE)'],
#     'publication_info': {'journal_title': 'Phys.Lett.B',
#      'journal_volume': '696',
#      'page_end': '337',
#      'page_start': '328',
#      'year': 2011}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[4] T. Matsui H. Satz, Phys. Lett. B178 (1986) 416–422.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/230496'},
#    'reference': {'authors': [{'full_name': 'Satz'},
#      {'full_name': 'H., T. Matsui'}],
#     'label': '4',
#     'publication_info': {'journal_title': 'Phys.Lett.B',
#      'journal_volume': '178',
#      'page_end': '422',
#      'page_start': '416',
#      'year': 1986}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[5] P. Braun-Munzinger J. Stachel, Phys. Lett. B490 (2000) 196– 202.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/530943'},
#    'reference': {'authors': [{'full_name': 'Stachel'},
#      {'full_name': 'J., P. Braun-Munzinger'}],
#     'label': '5',
#     'publication_info': {'journal_title': 'Phys.Lett.B',
#      'journal_volume': '490',
#      'page_end': '202',
#      'page_start': '196',
#      'year': 2000}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[6] R. L. Thews et al., Phys. Rev. C 63 (2001) 054905.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/530975'},
#    'reference': {'authors': [{'full_name': 'Thews, R.L.'}],
#     'label': '6',
#     'publication_info': {'artid': '054905',
#      'journal_title': 'Phys.Rev.C',
#      'journal_volume': '63',
#      'year': 2001}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[7] K. Aamodt et al. (ALICE), JINST 3 (2008) S08002.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/796251'},
#    'reference': {'authors': [{'full_name': 'Aamodt, K.'}],
#     'label': '7',
#     'misc': ['(ALICE)'],
#     'publication_info': {'artid': 'S08002',
#      'journal_title': 'JINST',
#      'journal_volume': '3',
#      'year': 2008}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[8] B. B. Abelev et al. (ALICE), Int. J. Mod. Phys. A29 (2014) 1430044.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/1281831'},
#    'reference': {'authors': [{'full_name': 'Abelev, B.B.'}],
#     'label': '8',
#     'misc': ['(ALICE)'],
#     'publication_info': {'artid': '1430044',
#      'journal_title': 'Int.J.Mod.Phys.A',
#      'journal_volume': '29',
#      'year': 2014}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[9] K. Aamodt et al. (ALICE), Phys. Lett. B 704 (2011) 442–455.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/897764'},
#    'reference': {'authors': [{'full_name': 'Aamodt, K.'}],
#     'label': '9',
#     'misc': ['(ALICE)'],
#     'publication_info': {'journal_title': 'Phys.Lett.B',
#      'journal_volume': '704',
#      'page_end': '455',
#      'page_start': '442',
#      'year': 2011}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[10] S. Acharya et al. (ALICE), JHEP 10 (2019) 084.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/1735351'},
#    'reference': {'authors': [{'full_name': 'Acharya, S.'}],
#     'label': '10',
#     'misc': ['(ALICE)'],
#     'publication_info': {'artid': '084',
#      'journal_title': 'JHEP',
#      'journal_volume': '10',
#      'page_start': '084',
#      'year': 2019}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[11] S. Acharya et al. (ALICE), Eur. Phys. J. C 77 (6) (2017) 392.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/1511865'},
#    'reference': {'authors': [{'full_name': 'Acharya, S.'}],
#     'label': '11',
#     'misc': ['(ALICE)'],
#     'publication_info': {'artid': '392',
#      'journal_title': 'Eur.Phys.J.C',
#      'journal_volume': '77',
#      'page_start': '392',
#      'year': 2017}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[12] S. Acharya et al. (ALICE), Phys. Lett. B 810 (2020) 135758.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/1797445'},
#    'reference': {'authors': [{'full_name': 'Acharya, S.'}],
#     'label': '12',
#     'misc': ['(ALICE)'],
#     'publication_info': {'artid': '135758',
#      'journal_title': 'Phys.Lett.B',
#      'journal_volume': '810',
#      'year': 2020}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[13] B. Kopeliovich et al., Phys. Rev. D 88 (11) (2013) 116002.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/1249402'},
#    'reference': {'authors': [{'full_name': 'Kopeliovich, B.'}],
#     'label': '13',
#     'publication_info': {'artid': '116002',
#      'journal_title': 'Phys.Rev.D',
#      'journal_volume': '88',
#      'year': 2013}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[14] E. Ferreiro C. Pajares, Phys. Rev. C 86 (2012) 034903.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/1095124'},
#    'reference': {'authors': [{'full_name': 'Pajares'},
#      {'full_name': 'C., E. Ferreiro'}],
#     'label': '14',
#     'publication_info': {'artid': '034903',
#      'journal_title': 'Phys.Rev.C',
#      'journal_volume': '86',
#      'year': 2012}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[15] E. Levin et al., Eur. Phys. J. C 80 (6) (2020) 560.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/1762206'},
#    'reference': {'authors': [{'full_name': 'Levin, E.'}],
#     'label': '15',
#     'publication_info': {'artid': '560',
#      'journal_title': 'Eur.Phys.J.C',
#      'journal_volume': '80',
#      'page_start': '560',
#      'year': 2020}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[16] Y.-Q. Ma et al., Phys. Rev. D 98 (7) (2018) 074025.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/1665216'},
#    'reference': {'authors': [{'full_name': 'Ma, Y.-Q.'}],
#     'label': '16',
#     'publication_info': {'artid': '074025',
#      'journal_title': 'Phys.Rev.D',
#      'journal_volume': '98',
#      'year': 2018}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[17] K. Werner et al., Phys. Rev. C 89 (6) (2014) 064903.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/1267467'},
#    'reference': {'authors': [{'full_name': 'Werner, K.'}],
#     'label': '17',
#     'publication_info': {'artid': '064903',
#      'journal_title': 'Phys.Rev.C',
#      'journal_volume': '89',
#      'year': 2014}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[18] S. Acharya et al. (ALICE), JHEP 07 (2020) 237.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/1785315'},
#    'reference': {'authors': [{'full_name': 'Acharya, S.'}],
#     'label': '18',
#     'misc': ['(ALICE)'],
#     'publication_info': {'artid': '237',
#      'journal_title': 'JHEP',
#      'journal_volume': '07',
#      'page_start': '237',
#      'year': 2020}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[19] B. Duclou´ e et al., Phys. Rev. D 94 (7) (2016) 074031.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/1460848'},
#    'reference': {'authors': [{'full_name': 'Duclou, B.'}],
#     'label': '19',
#     'publication_info': {'artid': '074031',
#      'journal_title': 'Phys.Rev.D',
#      'journal_volume': '94',
#      'year': 2016}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[20] J. L. Albacete et al., Nucl. Phys. A 972 (2018) 18–85.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/1613697'},
#    'reference': {'authors': [{'full_name': 'Albacete, J.L.'}],
#     'label': '20',
#     'publication_info': {'journal_title': 'Nucl.Phys.A',
#      'journal_volume': '972',
#      'page_end': '85',
#      'page_start': '18',
#      'year': 2018}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[21] A. Kusina et al., Phys. Rev. Lett. 121 (5) (2018) 052004.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/1644102'},
#    'reference': {'authors': [{'full_name': 'Kusina, A.'}],
#     'label': '21',
#     'publication_info': {'artid': '052004',
#      'journal_title': 'Phys.Rev.Lett.',
#      'journal_volume': '121',
#      'year': 2018}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[22] F. Arleo S. Peign´ e, JHEP 10 (2014) 073.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/1306904'},
#    'reference': {'authors': [{'full_name': 'Peign'},
#      {'full_name': 'S., F. Arleo'}],
#     'label': '22',
#     'publication_info': {'artid': '073',
#      'journal_title': 'JHEP',
#      'journal_volume': '10',
#      'page_start': '073',
#      'year': 2014}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[23] S. Acharya et al. (ALICE), Phys. Lett. B 806 (2020) 135486.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/1762360'},
#    'reference': {'authors': [{'full_name': 'Acharya, S.'}],
#     'label': '23',
#     'misc': ['(ALICE)'],
#     'publication_info': {'artid': '135486',
#      'journal_title': 'Phys.Lett.B',
#      'journal_volume': '806',
#      'year': 2020}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[24] R. Aaij et al. (LHCb), JHEP 11 (2018) 194.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/1699106'},
#    'reference': {'authors': [{'full_name': 'Aaij, R.'}],
#     'label': '24',
#     'misc': ['(LHCb)'],
#     'publication_info': {'artid': '194',
#      'journal_title': 'JHEP',
#      'journal_volume': '11',
#      'page_start': '194',
#      'year': 2018}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[25] J.-P. Lansberg H.-S. Shao, Eur. Phys. J. C 77 (1) (2017) 1.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/1492537'},
#    'reference': {'authors': [{'full_name': 'Shao'},
#      {'full_name': 'H.-S., J.-P. Lansberg'}],
#     'label': '25',
#     'publication_info': {'artid': '1',
#      'journal_title': 'Eur.Phys.J.C',
#      'journal_volume': '77',
#      'page_start': '1',
#      'year': 2017}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[26] E. G. Ferreiro, PoS DIS2018 (2018) 130.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/1701246'},
#    'reference': {'authors': [{'full_name': 'Ferreiro, E.G.'}],
#     'label': '26',
#     'publication_info': {'artid': '130',
#      'journal_title': 'PoS',
#      'journal_volume': 'DIS2018',
#      'page_start': '130',
#      'year': 2018}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[27] S. Acharya et al. (ALICE), Phys. Lett. B 805 (2020) 135434.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/1762353'},
#    'reference': {'authors': [{'full_name': 'Acharya, S.'}],
#     'label': '27',
#     'misc': ['(ALICE)'],
#     'publication_info': {'artid': '135434',
#      'journal_title': 'Phys.Lett.B',
#      'journal_volume': '805',
#      'year': 2020}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[28] A. Andronic et al., Phys. Lett. B 652 (2007) 259–261.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/743262'},
#    'reference': {'authors': [{'full_name': 'Andronic, A.'}],
#     'label': '28',
#     'publication_info': {'journal_title': 'Phys.Lett.B',
#      'journal_volume': '652',
#      'page_end': '261',
#      'page_start': '259',
#      'year': 2007}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[29] X. Zhao R. Rapp, Nuclear Physics A 859 (1) (2011) 114 – 125.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/889124'},
#    'reference': {'authors': [{'full_name': 'Rapp'},
#      {'full_name': 'R., X. Zhao'}],
#     'label': '29',
#     'publication_info': {'journal_title': 'Nucl.Phys.A',
#      'journal_volume': '859',
#      'page_end': '125',
#      'page_start': '114',
#      'year': 2011}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[30] K. Zhou et al., Phys. Rev. C 89 (2014) 054911.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/1278586'},
#    'reference': {'authors': [{'full_name': 'Zhou, K.'}],
#     'label': '30',
#     'publication_info': {'artid': '054911',
#      'journal_title': 'Phys.Rev.C',
#      'journal_volume': '89',
#      'year': 2014}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[31] E. Ferreiro, Physics Letters B 731 (2014) 57 – 63.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/1190365'},
#    'reference': {'authors': [{'full_name': 'Ferreiro, E.'}],
#     'label': '31',
#     'publication_info': {'journal_title': 'Phys.Lett.B',
#      'journal_volume': '731',
#      'page_end': '63',
#      'page_start': '57',
#      'year': 2014}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[32] S. Acharya et al. (ALICE), JHEP 02 (2020) 041.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/1753083'},
#    'reference': {'authors': [{'full_name': 'Acharya, S.'}],
#     'label': '32',
#     'misc': ['(ALICE)'],
#     'publication_info': {'artid': '041',
#      'journal_title': 'JHEP',
#      'journal_volume': '02',
#      'page_start': '041',
#      'year': 2020}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[33] S. Acharya et al. (ALICE), JHEP 10 (2020) 141.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/1798507'},
#    'reference': {'authors': [{'full_name': 'Acharya, S.'}],
#     'label': '33',
#     'misc': ['(ALICE)'],
#     'publication_info': {'artid': '141',
#      'journal_title': 'JHEP',
#      'journal_volume': '10',
#      'page_start': '141',
#      'year': 2020}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[34] S. Acharya et al. (ALICE)arXiv:2005.11131.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/1797463'},
#    'reference': {'arxiv_eprint': '2005.11131',
#     'authors': [{'full_name': 'Acharya, S.'}],
#     'label': '34',
#     'misc': ['(ALICE)']}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[35] S. Acharya et al. (ALICE), JHEP 09 (2018) 006.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/1672822'},
#    'reference': {'authors': [{'full_name': 'Acharya, S.'}],
#     'label': '35',
#     'misc': ['(ALICE)'],
#     'publication_info': {'artid': '006',
#      'journal_title': 'JHEP',
#      'journal_volume': '09',
#      'page_start': '006',
#      'year': 2018}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[36] X. Du, R. Rapp M. He, Phys. Rev. C 96 (5) (2017) 054901.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/1607808'},
#    'reference': {'authors': [{'full_name': 'Du, X.'},
#      {'full_name': 'He'},
#      {'full_name': 'M., R. Rapp'}],
#     'label': '36',
#     'publication_info': {'artid': '054901',
#      'journal_title': 'Phys.Rev.C',
#      'journal_volume': '96',
#      'year': 2017}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[37] S. Acharya et al. (ALICE), Phys. Rev. Lett. 123 (19) (2019) 192301.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/1742764'},
#    'reference': {'authors': [{'full_name': 'Acharya, S.'}],
#     'label': '37',
#     'misc': ['(ALICE)'],
#     'publication_info': {'artid': '192301',
#      'journal_title': 'Phys.Rev.Lett.',
#      'journal_volume': '123',
#      'year': 2019}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[38] P. P. Bhaduri et al., Phys. Rev. C 100 (5) (2019) 051901.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/1694148'},
#    'reference': {'authors': [{'full_name': 'Bhaduri, P.P.'}],
#     'label': '38',
#     'publication_info': {'artid': '051901',
#      'journal_title': 'Phys.Rev.C',
#      'journal_volume': '100',
#      'year': 2019}}},
#   {'curated_relation': False,
#    'raw_refs': [{'schema': 'text',
#      'value': '[39] K. Reygers et al., Phys. Rev. C 101 (6) (2020) 064905.'}],
#    'record': {'ref': 'https://inspirehep.net/api/literature/1762346'},
#    'reference': {'authors': [{'full_name': 'Reygers, K.'}],
#     'label': '39',
#     'publication_info': {'artid': '064905',
#      'journal_title': 'Phys.Rev.C',
#      'journal_volume': '101',
#      'year': 2020}}}],
#  'titles': [{'source': 'arXiv',
#    'title': 'Measurement of quarkonium production in ALICE'}]}

# %%
journal_info_keys[6]
# Out:
# dict_keys(['artid', 'journal_title', 'journal_issue', 'year', 'journal_volume'])

# %%
df['metadata'][6]
# Out:
# {'arxiv_eprints': [{'categories': ['physics.gen-ph'], 'value': '1503.00620'}],
#  'author_count': 3,
#  'authors': [{'affiliations': [{'record': {'ref': 'https://inspirehep.net/api/institutions/903784'},
#      'value': 'Denmark, Tech. U.'}],
#    'bai': 'O.L.Trinhammer.1',
#    'full_name': 'Trinhammer, Ole L.'},
#   {'affiliations': [{'record': {'ref': 'https://inspirehep.net/api/institutions/903784'},
#      'value': 'Denmark, Tech. U.'}],
#    'bai': 'H.G.Bohr.2',
#    'full_name': 'Bohr, Henrik G.'},
#   {'affiliations': [{'record': {'ref': 'https://inspirehep.net/api/institutions/903784'},
#      'value': 'Denmark, Tech. U.'}],
#    'bai': 'M.S.Jensen.1',
#    'full_name': 'Jensen, Mogens Stibius'}],
#  'citation_count': 9,
#  'citation_count_without_self_citations': 1,
#  'control_number': 1347055,
#  'document_type': ['article'],
#  'inspire_categories': [{'term': 'General Physics'}],
#  'preprint_date': '2014-12-07',
#  'publication_info': [{'artid': '1550078',
#    'journal_issue': '14',
#    'journal_title': 'Int.J.Mod.Phys.A',
#    'journal_volume': '30',
#    'year': 2015}],
#  'referenced_authors_bais': ['A.A.Abdelalim.1',
#   'A.Abdulsalam.2',
#   'A.A.Bhatti.1',
#   'A.Adair.1',
#   'A.Adametz.1',
#   'A.Adiguzel.1',
#   'A.A.E.Bannoura.1',
#   'A.Agapitos.1',
#   'A.A.Grebenyuk.1',
#   'A.Akimov.1',
#   'A.A.Komar.1',
#   'A.A.Korol.1',
#   'A.Aleksandrov.1',
#   'A.A.Lobanov.1',
#   'A.Alonso.2',
#   'A.A.Maier.1',
#   'A.A.Minaenko.1',
#   'A.Amorim.1',
#   'A.Anastassov.1',
#   'A.Andreazza.1',
#   'A.Andres.Ocampo.Rios.1',
#   'A.A.Nepomuceno.1',
#   'A.Angerami.1',
#   'A.Anisenkov.1',
#   'A.Anisimov.2',
#   'A.Anjos.1',
#   'A.Antonaki.1',
#   'A.Antonov.1',
#   'A.A.Paramonov.1',
#   'A.A.Poblaguev.1',
#   'A.Apresyan.1',
#   'A.Apyan.1',
#   'Aaron.J.Armbruster.1',
#   'A.A.Salnikov.1',
#   'A.A.Savin.1',
#   'A.Ashkenazi.1',
#   'A.Askew.1',
#   'A.A.Solodkov.1',
#   'A.A.Spiridonov.1',
#   'A.Astbury.1',
#   'A.Attikis.1',
#   'A.Aubin.1',
#   'A.Avetisyan.2',
#   'A.A.Volkov.1',
#   'A.Baas.1',
#   'A.Bach.1',
#   'A.Baden.1',
#   'A.Barbaro.Galtieri.1',
#   'A.Barczyk.1',
#   'A.Baroncelli.1',
#   'A.Bartoloni.1',
#   'A.Bassalat.1',
#   'A.Basti.1',
#   'A.Battaglia.1',
#   'Abdollah.Mohammadi.1',
#   'A.Bellerive.1',
#   'A.Belloni.1',
#   'A.Belousov.1',
#   'A.Belyaev.1',
#   'A.Bertin.1',
#   'A.Besson.1',
#   'A.Bethani.1',
#   'A.B.Gridnev.1',
#   'A.Bingul.1',
#   'A.B.Lodge.1',
#   'A.Blondel.1',
#   'A.B.Meyer.1',
#   'A.Bocci.1',
#   'A.Bocci.2',
#   'A.Bodek.2',
#   'A.Bogouch.1',
#   'A.Bonato.1',
#   'A.Bornheim.2',
#   'A.Boveia.1',
#   'A.Branca.1',
#   'A.Branson.1',
#   'A.Brez.2',
#   'A.Brinkerhoff.1',
#   'A.Bruni.2',
#   'A.Buckley.1',
#   'A.Bujak.1',
#   'A.Bundock.1',
#   'A.Burgmeier.1',
#   'A.Butler.1',
#   'A.Buzatu.1',
#   'A.Cakir.1',
#   'A.Calamba.1',
#   'A.Calandri.1',
#   'A.Calcaterra.1',
#   'A.Campoverde.1',
#   'A.Canepa.1',
#   'A.Carboni.1',
#   'A.Castelli.1',
#   'A.Castro.1',
#   'A.Catinaccio.1',
#   'A.Cattai.1',
#   'A.C.Benvenuti.1',
#   'A.C.Daniells.1',
#   'A.Cecchi.1',
#   'A.Ceccucci.1',
#   'A.Cerri.1',
#   'A.Cervelli.1',
#   'A.C.Forti.1',
#   'A.Chafaq.1',
#   'A.Charkiewicz.2',
#   'A.Chatterjee.1',
#   'A.Chavez.1',
#   'A.Chegwidden.1',
#   'A.Chilingarov.1',
#   'Achim.Stahl.1',
#   'A.Chisholm.1',
#   'A.Chitan.2',
#   'A.Christov.1',
#   'A.Ciampa.1',
#   'A.Ciocio.1',
#   'A.C.Konig.1',
#   'A.C.Kraan.1',
#   'A.C.Le.Bihan.1',
#   'A.C.Marini.1',
#   'A.C.Mignerey.1',
#   'A.Coccaro.1',
#   'A.Colaleo.1',
#   'A.Cortes.Gonzalez.1',
#   'A.C.Schaffer.1',
#   'A.Custodio.1',
#   'A.C.Wren.1',
#   'A.Dabrowski.1',
#   'A.Dafinca.1',
#   'A.D.Altheimer.1',
#   'Adam.Elwood.1',
#   'A.Dattagupta.1',
#   'A.David.Tinoco.Mendes.1',
#   'A.D.Bukin.1',
#   'A.De.Benedetti.1',
#   'A.de.Cosa.1',
#   'A.Degano.1',
#   'A.de.Gouvea.1',
#   'A.Deisher.1',
#   'A.Dell.Acqua.1',
#   'A.Demilly.1',
#   'A.Demiyanov.1',
#   'A.Dermenev.1',
#   'A.De.Roeck.1',
#   'A.De.Salvo.1',
#   'A.De.Santo.1',
#   'A.Descroix.1',
#   'A.Dewhurst.1',
#   'A.Di.Ciaccio.1',
#   'A.Di.Domenico.1',
#   'A.Dierlamm.1',
#   'A.Di.Girolamo.1',
#   'A.Di.Mattia.1',
#   'A.Dimitrievska.1',
#   'A.Dimitrov.1',
#   'A.Dishaw.1',
#   'A.Di.Simone.1',
#   'A.D.Orazio.1',
#   'A.Doria.1',
#   'A.Dotti.1',
#   'A.Doxiadis.1',
#   'A.D.Panagiotou.1',
#   'A.D.Peris.1',
#   'Adrien.Caudron.1',
#   'A.Drozdetskiy.1',
#   'A.D.Ryabov.1',
#   'A.D.Sulimov.1',
#   'A.D.Tapper.1',
#   'A.Dudarev.1',
#   'A.Durglishvili.1',
#   'A.D.V.Wemans.1',
#   'A.E.Barton.1',
#   'A.E.Jensen.1',
#   'A.E.Kiryunin.1',
#   'A.Elliott.Peisert.1',
#   'A.Engl.2',
#   'A.E.Nuncio.Quiroz.1',
#   'A.Ereditato.1',
#   'A.Ershov.1',
#   'A.E.Rubin.1',
#   'A.Escalante.del.valle.1',
#   'A.E.Undrus.1',
#   'A.Everett.1',
#   'A.Ezhilov.1',
#   'A.Fagot.1',
#   'A.Fahim.1',
#   'A.Fanfani.1',
#   'A.Farilla.1',
#   'A.Favareto.1',
#   'A.F.Barfuss.1',
#   'A.F.Beretvas.1',
#   'A.Fedorov.1',
#   'A.Fenyuk.1',
#   'A.Fenyvesi.1',
#   'A.Ferrando.1',
#   'A.Ferrer.3',
#   'A.Ferretto.Parodi.1',
#   'A.Filipcic.1',
#   'A.Firan.1',
#   'A.Fischer.1',
#   'A.Floderus.1',
#   'A.Florent.1',
#   'A.Flossdorf.1',
#   'A.Formica.1',
#   'A.F.Osorio.Oliveros.1',
#   'A.Fowler.1',
#   'A.F.Saavedra.1',
#   'A.Furgeri.1',
#   'A.Gabareen.mokhtar.1',
#   'A.Gabrielli.2',
#   'A.Gaddi.1',
#   'A.Gaponenko.1',
#   'A.Garabedian.1',
#   'A.Garcia.Bellido.1',
#   'A.Gay.1',
#   'A.Gaz.1',
#   'A.G.Bogdanchikov.1',
#   'A.G.Clark.1',
#   'A.G.Delannoy.1',
#   'A.G.Denig.1',
#   'A.Geiser.1',
#   'A.Gemmell.1',
#   'A.Gershon.1',
#   'A.Gessler.1',
#   'A.Ghezzi.1',
#   'A.Giammanco.1',
#   'A.Giassi.1',
#   'A.Gibson.1',
#   'A.Givernaud.1',
#   'A.Gizhko.1',
#   'A.G.Krivshich.1',
#   'A.Glazov.1',
#   'A.G.Leister.2',
#   'A.Go.5',
#   'A.Godshalk.1',
#   'A.Golunov.1',
#   'A.Gorisek.1',
#   'Agostinho.Gomes.1',
#   'A.Goussiou.1',
#   'A.Gozzelino.2',
#   'A.Graziano.1',
#   'A.Gribushin.1',
#   'A.Grillo.2',
#   'A.Grohsjean.1',
#   'A.Gude.1',
#   'A.Guneratne.Bryer.1',
#   'A.Gurrola.1',
#   'A.Gurtu.1',
#   'A.G.Volodko.1',
#   'A.Hafner.1',
#   'A.H.Aly.1',
#   'A.Hamilton.1',
#   'A.Hard.1',
#   'A.Harel.1',
#   'A.Hart.1',
#   'A.Harvey.1',
#   'A.Hasib.1',
#   'A.Hauke.1',
#   'A.Hawkins.1',
#   'A.H.Ball.1',
#   'A.Heiss.1',
#   'A.Heister.1',
#   'A.Hektor.1',
#   'A.Henrichs.1',
#   'A.Hernandez.Almada.1',
#   'A.Herve.1',
#   'A.H.Heering.1',
#   'A.Hinzmann.1',
#   'A.Holloway.1',
#   'A.Holtkamp.1',
#   'A.Holzner.1',
#   'A.Hoummada.1',
#   'A.Hunt.2',
#   'A.Huttmann.1',
#   'A.I.Butt.1',
#   'A.I.Etienvre.1',
#   'A.I.Malakhov.1',
#   'A.Iordanova.1',
#   'A.Irles.Quiles.1',
#   'A.Ivanov.2',
#   'A.Ivashin.1',
#   'A.Jafari.2',
#   'A.Jantsch.1',
#   'A.Jawahery.1',
#   'Ajay.Kumar.1',
#   'A.J.Barr.1',
#   'A.J.Bell.1',
#   'A.J.Bevan.1',
#   'A.J.Brennan.1',
#   'A.J.Campbell.1',
#   'A.J.Edwards.1',
#   'A.Jinaru.2',
#   'A.J.Lankford.1',
#   'A.J.Stewart.Smith.1',
#   'A.Junkes.1',
#   'A.Juodagalvis.1',
#   'A.J.Washbrook.1',
#   'A.J.Zsigmond.1',
#   'A.Kaczmarska.1',
#   'A.Kalinin.1',
#   'A.Kalinowski.1',
#   'A.Kalogeropoulos.1',
#   'A.Kamenev.1',
#   'A.Kamenshchikov.1',
#   'A.Kaminskiy.1',
#   'A.Kapliy.1',
#   'A.Karjalainen.1',
#   'A.Karneyeu.1',
#   'A.Karyukhin.1',
#   'A.Kasmi.1',
#   'A.Kastanas.1',
#   'A.Katre.2',
#   'A.K.Becker.1',
#   'A.K.Ciftci.1',
#   'A.Khan.2',
#   'A.Khanov.1',
#   'A.Kharchilava.1',
#   'A.Khodinov.1',
#   'A.Khomich.1',
#   'A.K.Honma.1',
#   'A.Khoroshilov.1',
#   'A.Khukhunaishvili.1',
#   'Akira.Yamamoto.1',
#   'A.K.Kalsi.1',
#   'A.K.Kopp.1',
#   'A.Klier.1',
#   'A.Klimentov.1',
#   'A.K.Mohanty.1',
#   'A.K.Mohapatra.1',
#   'A.K.Morley.1',
#   'A.Knue.1',
#   'A.Knutsson.1',
#   'A.Kononov.1',
#   'A.Konoplyannikov.1',
#   'A.Kopecky.1',
#   'A.Korablev.1',
#   'A.K.Orlov.1',
#   'A.Korn.2',
#   'A.Kornmayer.1',
#   'A.Korpela.1',
#   'A.Korytov.1',
#   'A.Koutsman.1',
#   'A.Krasznahorkay.1',
#   'A.Kravchenko.1',
#   'A.Krokhotin.2',
#   'A.Kropivnitskaya.1',
#   'A.Kruse.1',
#   'A.Kryukov.1',
#   'A.K.Sanchez.1',
#   'A.K.Topaksu.1',
#   'A.Kubik.1',
#   'A.Kugel.1',
#   'A.Kuhl.2',
#   'A.Kumar.4',
#   'A.Kumar.5',
#   'A.Kunsken.1',
#   'A.Kupco.1',
#   'A.K.Yarritu.1',
#   'A.Kyriakis.1',
#   'Alan.A.Hahn.1',
#   'A.Lanaro.1',
#   'Alan.D.Martin.1',
#   'A.Lanev.1',
#   'Alan.F.Sill.1',
#   'A.Larner.1',
#   'A.La.Rosa.1',
#   'A.Lath.1',
#   'A.Law.1',
#   'A.Lazzaro.1',
#   'Alberto.Aloisio.1',
#   'Alberto.Annovi.1',
#   'Alberto.Ruiz.Jimeno.1',
#   'Alberto.Sanchez.Hernandez.1',
#   'A.Ledovskoy.2',
#   'A.Lehan.1',
#   'A.Leisos.1',
#   'Alejandro.Perez.2',
#   'Alessandro.Manfredini.1',
#   'Alessandro.Montanari.1',
#   'A.Levin.1',
#   'A.Levine.1',
#   'A.Levine.2',
#   'A.Lewis.3',
#   'Alexander.L.Read.1',
#   'Alexander.S.Sakharov.1',
#   'A.Leyko.2',
#   'Alfredo.M.Castaneda.Hernandez.1',
#   'Alice.L.Bean.1',
#   'Alicia.Calderon.1',
#   'A.Limosani.1',
#   'A.Lipniacka.1',
#   'Alison.Lister.1',
#   'A.Litomin.1',
#   'Allen.I.Mincer.1',
#   'A.Lleres.1',
#   'A.L.Lyubimov.1',
#   'A.Loginov.1',
#   'A.L.onard.4',
#   'A.Lopez.2',
#   'A.Lopez.Virto.1',
#   'A.Lounis.1',
#   'A.Lowe.1',
#   'A.L.Pequegnot.1',
#   'A.L.Schorlemmer.1',
#   'A.Lucaroni.1',
#   'A.Lucotte.1',
#   'A.Ludwig.1',
#   'A.Lusiani.1',
#   'A.Luthra.1',
#   'A.L.Yen.1',
#   'A.Macchiolo.1',
#   'A.Madorsky.1',
#   'A.Madsen.1',
#   'A.Makovec.1',
#   'A.Manabe.1',
#   'A.Mann.2',
#   'A.Manousakis.Katsikakis.2',
#   'A.Mapelli.1',
#   'A.Marchioro.1',
#   'A.Marinov.1',
#   'A.Markina.1',
#   'A.Markou.1',
#   'A.Martelli.1',
#   'A.Martinez.4',
#   'A.Martyniuk.1',
#   'A.Marzin.1',
#   'A.Maslennikov.1',
#   'A.Masoni.1',
#   'A.Massironi.1',
#   'A.Mastroberardino.1',
#   'A.M.Awad.1',
#   'A.Mayne.1',
#   'A.M.Bangert.1',
#   'A.McCarn.Deiana.1',
#   'A.M.Cooper.Sarkar.1',
#   'A.Meade.1',
#   'A.Mehta.1',
#   'A.M.Eisner.1',
#   'Amelia.Maio.1',
#   'A.Melo.1',
#   'A.Menchikov.2',
#   'A.Meneguzzo.1',
#   'A.Mengarelli.1',
#   'A.Messina.1',
#   'A.Messineo.1',
#   'A.Mestvirishvili.1',
#   'A.M.Fomenko.1',
#   'A.M.Guler.1',
#   'A.M.Henriques.2',
#   'A.Milic.1',
#   'A.Milov.2',
#   'Amir.Farbin.1',
#   'Amitava.Roy.1',
#   'A.Miucci.1',
#   'A.M.Kurenkov.1',
#   'A.M.Litke.1',
#   'A.M.Lutz.1',
#   'A.M.Magnan.1',
#   'A.M.Mahrous.1',
#   'A.M.Makankin.1',
#   'A.M.Nairz.1',
#   'A.Modak.1',
#   'A.Moeller.1',
#   'A.Moggi.1',
#   'A.Molfetas.2',
#   'A.Moraes.1',
#   'A.Morelos.Pineda.1',
#   'A.Morozov.2',
#   'A.Mott.1',
#   'A.M.Pingel.1',
#   'A.M.Rahimi.1',
#   'A.Mrak.tadel.2',
#   'A.M.Rossi.1',
#   'A.M.Ruland.1',
#   'A.M.Sirunyan.1',
#   'A.M.Snigirev.1',
#   'A.M.Sukharev.1',
#   'A.Mughal.1',
#   'A.Mussgiller.1',
#   'A.Myagkov.1',
#   'A.M.Zaitsev.1',
#   'A.M.Zanetti.1',
#   'A.Nagarkar.1',
#   'A.N.Aleev.1',
#   'A.Napier.1',
#   'A.Nappi.1',
#   'A.Nayak.1',
#   'Andrea.D.Benaglia.1',
#   'Andrea.Gabrielli.2',
#   'Andrea.Parenti.1',
#   'Andreas.Guth.1',
#   'Andreas.Hoecker.1',
#   'Andreas.Piepke.1',
#   'Andrea.Ventura.1',
#   'Andrei.Artamonov.1',
#   'Andrew.Beddall.1',
#   'Andrew.C.Haas.1',
#   'Andrew.G.Brandt.1',
#   'Andrew.Gilbert.1',
#   'Andrew.P.White.1',
#   'Andrew.Rose.1',
#   'A.Negri.1',
#   'A.Nelson.1',
#   'A.Neusiedl.1',
#   'A.Neveu.1',
#   'A.Nikiforov.1',
#   'A.Nikitenko.1',
#   'A.Nisati.1',
#   'A.N.Maksimov.1',
#   'Anna.Cimmino.1',
#   'Anna.E.Woodard.1',
#   'A.Nowack.1',
#   'A.N.rnberg.1',
#   'A.N.Rozanov.1',
#   'A.N.Safonov.1',
#   'A.N.Skachkova.1',
#   'Antony.A.Carter.1',
#   'A.N.Tuna.1',
#   'A.Ochi.2',
#   'A.Oehler.1',
#   'A.Oh.2',
#   'A.Olariu.1',
#   'A.Olbrechts.2',
#   'A.Olchevski.1',
#   'A.Olszewski.1',
#   'A.O.M.Iorio.1',
#   'A.Onnela.1',
#   'A.Onofre.1',
#   'A.Ostapchuk.1',
#   'A.Ouraou.1',
#   'A.Ovcharova.1',
#   'A.Oyanguren.1',
#   'A.Ozpineci.1',
#   'A.Palano.1',
#   'A.Palma.2',
#   'A.Papadelis.1',
#   'A.Papageorgiou.1',
#   'A.Pashenkov.1',
#   'A.Passeri.1',
#   'A.P.Cheplakov.1',
#   'A.P.Colijn.1',
#   'A.Penson.1',
#   'A.Penzo.1',
#   'A.Perez.Calero.Yzquierdo.1',
#   'A.Perieanu.1',
#   'A.Perloff.2',
#   'A.Perrotta.1',
#   'A.Peterman.2',
#   'A.Petrella.1',
#   'A.Petridis.1',
#   'A.Petrilli.1',
#   'A.Petrosyan.1',
#   'A.Petrucci.1',
#   'A.Petrukhin.1',
#   'A.Petzold.1',
#   'A.Pfeiffer.1',
#   'A.Phan.1',
#   'A.Picazio.1',
#   'A.Pilkington.1',
#   'A.Pin.3',
#   'A.Pinder.1',
#   'A.Polatoz.1',
#   'A.Policicchio.1',
#   'A.Polini.1',
#   'A.Poll.2',
#   'A.Pomarol.1',
#   'A.Pompili.1',
#   'A.P.Onuchin.1',
#   'A.Popov.15',
#   'A.Poppleton.1',
#   'A.Poschlad.1',
#   'A.Potenza.2',
#   'A.Pozdnyakov.1',
#   'A.P.Pages.1',
#   'A.Prokes.1',
#   'A.Pronko.1',
#   'A.Psallidas.2',
#   'A.Pullia.1',
#   'A.P.Wagner.1',
#   'A.Quadt.1',
#   'A.Quintario.olmeda.1',
#   'A.Qureshi.1',
#   'A.Racz.1',
#   'A.Radi.1',
#   'A.Radu.2',
#   'A.Randle.Conde.1',
#   'A.Ranieri.1',
#   'A.Raspereza.1',
#   'A.Raval.1',
#   'A.R.Buzykaev.1',
#   'Archana.Sharma.2',
#   'A.R.Davison.2',
#   'A.R.Drager.1',
#   'A.Redelbach.1',
#   'A.Reinsch.1',
#   'A.Renaud.1',
#   'Ariel.G.Schwartzman.1',
#   'A.Rimoldi.1',
#   'A.Rinkevicius.1',
#   'A.Rizzi.1',
#   'A.R.Liddle.1',
#   'Arnaud.Ferrari.1',
#   'Arnd.Meyer.1',
#   'A.Robichaud.Veronneau.1',
#   'A.Robson.1',
#   'A.Roe.2',
#   'A.Romaniouk.1',
#   'A.Romero.1',
#   'A.Ronzhin.1',
#   'A.Roodman.1',
#   'A.Rose.6',
#   'A.Rosowsky.1',
#   'Arther.E.Snyder.1',
#   'Arturo.Sanchez.1',
#   'A.Ruiz.Martinez.1',
#   'Arun.Kumar.1',
#   'A.Ruschke.1',
#   'A.R.Weidberg.1',
#   'A.Ryd.1',
#   'A.Sabellek.1',
#   'A.Saddique.1',
#   'A.Saha.2',
#   'A.Saha.3',
#   'A.Salamon.1',
#   'A.Salvucci.1',
#   'A.Salzburger.1',
#   'A.Sansoni.1',
#   'A.Santocchia.1',
#   'A.Santoro.1',
#   'A.Sapronov.1',
#   'A.Sartirana.1',
#   'A.Savoy.Navarro.1',
#   'A.S.Ayan.1',
#   'A.S.Belyaev.1',
#   'A.S.Boldyrev.1',
#   'A.Sbrizzi.1',
#   'A.S.Cabrera.1',
#   'A.S.Cerqueira.1',
#   'A.Schaelicke.2',
#   'A.Schamov.1',
#   'A.Scheurer.1',
#   'A.Schizzi.1',
#   'A.Schmidt.2',
#   'A.Schoning.1',
#   'A.Schultz.Von.Dratzig.2',
#   'A.S.Chvyrov.1',
#   'A.Sciaba.1',
#   'A.Seiden.1',
#   'A.Sfyrla.1',
#   'Ashfaq.Ahmad.1',
#   'A.Shmeleva.1',
#   'A.Shrinivas.1',
#   'Ashutosh.Bhardwaj.1',
#   'A.Sidoti.1',
#   'A.Singh.1',
#   'A.Singovsky.1',
#   'A.Sircar.1',
#   'A.Sisakyan.1',
#   'A.Skiba.1',
#   'A.S.Kozhin.1',
#   'A.Skuja.1',
#   'A.S.Mete.1',
#   'A.Smoron.1',
#   'A.Snesarev.1',
#   'A.Sobol.2',
#   'A.Soffer.1',
#   'A.Soha.1',
#   'A.Solano.1',
#   'A.Solin.2',
#   'A.Soloshenko.1',
#   'A.Solovey.1',
#   'A.Sood.2',
#   'A.Sopczak.1',
#   'A.Sparrow.1',
#   'A.Spiezia.1',
#   'A.S.Proskuryakov.1',
#   'A.Staiano.1',
#   'A.Starodumov.1',
#   'A.Staude.1',
#   'A.S.Thompson.1',
#   'A.Stocchi.1',
#   'A.Stradling.1',
#   'A.Straessner.1',
#   'A.Strandlie.1',
#   'A.Strumia.1',
#   'A.Succurro.1',
#   'A.Svyatkovskiy.1',
#   'A.S.Yoon.1',
#   'A.Sznajder.1',
#   'A.Taffard.1',
#   'A.Talyshev.1',
#   'A.Tanasijczuk.1',
#   'A.Tatarinov.1',
#   'A.Taurok.1',
#   'A.Tavares.delgado.1',
#   'A.T.Basye.1',
#   'A.T.Doyle.1',
#   'A.T.Goshaw.1',
#   'A.Thea.1',
#   'A.Theel.1',
#   'A.Tiko.2',
#   'A.Tiradani.1',
#   'A.T.Laasanen.1',
#   'A.Tonoyan.1',
#   'A.Topkar.1',
#   'A.Toropin.1',
#   'A.Tricoli.1',
#   'A.Tricomi.1',
#   'A.Tropiano.1',
#   'A.Trunov.1',
#   'A.Trzupek.1',
#   'A.T.Serban.1',
#   'A.Tsirou.1',
#   'A.Tua.1',
#   'A.Tudorache.1',
#   'A.Tumanov.1',
#   'A.Tumasyan.1',
#   'A.T.Warburton.1',
#   'A.T.Watson.1',
#   'A.Tykhonov.1',
#   'A.Ulyanov.2',
#   'Aurelio.Juste.Rozas.1',
#   'A.Usanova.1',
#   'A.Valero.2',
#   'A.Vanhoefer.1',
#   'A.Van.Spilbeeck.1',
#   'A.Vanyashin.2',
#   'A.Vartak.1',
#   'A.Vartapetian.1',
#   'A.V.Borisov.1',
#   'A.Venturi.1',
#   'A.Venturini.2',
#   'A.Vest.2',
#   'A.V.Ferapontov.1',
#   'A.V.Gritsan.1',
#   'A.Vilela.Pereira.1',
#   'Avinash.Dhar.1',
#   'A.V.Inyakin.2',
#   'A.V.Kotwal.1',
#   'A.V.Leonidov.1',
#   'A.V.Manohar.1',
#   'A.Vogel.1',
#   'A.Vogt.1',
#   'A.Volk.2',
#   'A.Vorobyev.1',
#   'A.Vorobyev.2',
#   'A.V.Pose.1',
#   'A.V.Telnov.1',
#   'A.V.Uzunian.1',
#   'A.V.Vinogradov.1',
#   'A.V.Zarubin.1',
#   'A.Waugh.1',
#   'A.W.Barker.1',
#   'A.Whitbeck.1',
#   'A.Wildauer.1',
#   'A.W.Wilson.1',
#   'A.Yagil.1',
#   'Ayda.Beddall.1',
#   'A.York.1',
#   'A.Y.Rodriguez.Marrero.1',
#   'A.Yurkewicz.1',
#   'A.Zabi.1',
#   'A.Zallo.1',
#   'A.Zaman.3',
#   'A.Zatzerklyaniy.1',
#   'A.Zaytsev.1',
#   'A.Zemla.1',
#   'A.Zhemchugov.1',
#   'A.Zhokin.1',
#   'A.Zibell.1',
#   'A.Zoccoli.1',
#   'A.Zucchetta.2',
#   'A.Zuranski.1',
#   'B.A.Barnett.1',
#   'B.Abi.1',
#   'B.A.Cole.1',
#   'B.A.Dobrescu.1',
#   'B.A.Dolgoshein.1',
#   'B.Akgun.1',
#   'B.A.Kulakov.1',
#   'B.Allbrooke.1',
#   'B.A.Long.1',
#   'Bannanje.Sripath.Acharya.1',
#   'B.A.Petersen.1',
#   'Barbara.Alvarez.Gonzalez.1',
#   'Barry.T.King.1',
#   'Bartlomiej.Zabinski.1',
#   'B.Asavapibhop.1',
#   'B.A.Schumm.1',
#   'B.Asman.1',
#   'B.Aubert.1',
#   'B.Auerbach.1',
#   'B.Baldin.1',
#   'B.Baumbaugh.1',
#   'B.Betchart.1',
#   'B.Bhawandeep.1',
#   'B.Bhuyan.1',
#   'B.Bilki.2',
#   'B.Bittner.1',
#   'B.Blau.1',
#   'B.Bockelman.1',
#   'B.Boimska.1',
#   'B.Brau.1',
#   'B.Brelier.1',
#   'B.B.Tannenwald.1',
#   'B.Budick.1',
#   'B.Burghgrave.1',
#   'B.Butler.1',
#   'B.Bylsma.1',
#   'B.Calpas.1',
#   'B.Calvert.1',
#   'B.Camanzi.1',
#   'B.Caron.1',
#   'B.Casal.Larana.2',
#   'B.C.Choudhary.1',
#   'B.Cerio.1',
#   'B.Chapleau.1',
#   'B.Clasie.1',
#   'B.Cleland.1',
#   'B.Clerbaux.1',
#   'B.Cooper.1',
#   'B.Courbon.1',
#   'B.Cox.1',
#   'B.C.Radburn.Smith.1',
#   'B.C.Shen.1',
#   'B.C.Smith.1',
#   'B.Cure.1',
#   'B.C.Wray.1',
#   'B.Dahmes.1',
#   'B.Dechenaux.2',
#   'B.De.La.Cruz.1',
#   'B.Demirkoz.1',
#   'B.DeWilde.1',
#   'B.D.Fields.1',
#   'B.Diamond.1',
#   'B.Di.Girolamo.1',
#   'B.D.Micco.1',
#   'B.Dorney.1',
#   'B.D.Schoenrock.1',
#   'B.D.Yabsley.1',
#   'B.Echenard.1',
#   'B.E.Cox.1',
#   'B.E.Lindquist.1',
#   'Benoit.Clement.1',
#   'B.Epp.1',
#   'Bernd.Stelzer.1',
#   'B.Esposito.1',
#   'B.Fabbro.1',
#   'B.Fatholahzadeh.1',
#   'B.Foster.2',
#   'B.Francis.1',
#   'B.Franek.1',
#   'B.Frisch.1',
#   'B.Galhardo.1',
#   'B.Gallop.1',
#   'B.Gaur.1',
#   'B.G.Chiladze.1',
#   'B.G.Fulsom.1',
#   'B.G.Gibbard.1',
#   'B.Giacobbe.1',
#   'B.Gobbi.1',
#   'B.Gobbo.1',
#   'B.Gomez.Moreno.1',
#   'B.Gorini.1',
#   'B.Gosdzik.1',
#   'B.G.Pope.1',
#   'B.G.Taylor.1',
#   'B.Guo.1',
#   'Bhawna.Gomber.1',
#   'B.Hegner.1',
#   'B.Heinemann.1',
#   'B.Heyburn.1',
#   'B.Holzman.1',
#   'B.Hong.1',
#   'B.Hooberman.1',
#   'B.H.Samset.1',
#   'B.Ille.1',
#   'Bing.Li.1',
#   'B.Isildak.1',
#   'B.Jackson.1',
#   'B.J.Blumenfeld.1',
#   'B.J.Kim.1',
#   'B.J.O.Brien.2',
#   'B.J.Smith.1',
#   'B.J.Wogsland.1',
#   'B.Kaplan.1',
#   'B.Kargoll.1',
#   'B.K.B.Chow.1',
#   'B.K.Gjelsten.1',
#   'B.K.Heltsley.1',
#   'B.Kilminster.1',
#   'B.Klein.1',
#   'B.Klima.1',
#   'B.Kreis.1',
#   'B.Krusche.1',
#   'B.Laforge.1',
#   'Blair.N.Ratcliff.1',
#   'B.L.Betev.1',
#   'B.Lee.2',
#   'B.Lemmer.1',
#   'B.Lenzi.1',
#   'B.Lewendel.1',
#   'B.Liberti.1',
#   'B.Lopez.paredes.1',
#   'B.Lundberg.1',
#   'B.Lund.Jensen.1',
#   'B.Lutz.1',
#   'B.L.Winer.1',
#   'B.Macek.1',
#   'B.Malaescu.1',
#   'B.Mandelli.2',
#   'B.Mangano.1',
#   'B.Mansoulie.1',
#   'B.Marangelli.2',
#   'B.Martin.3',
#   'B.Martin.Dit.Latour.1',
#   'B.Marzocchi.1',
#   'B.Mathias.1',
#   'B.M.Barnett.1',
#   'B.Meier.1',
#   'B.Meirose.1',
#   'B.Mellado.1',
#   'B.Michlin.1',
#   'B.Millan.Mejias.1',
#   'B.Mindur.1',
#   'B.M.Salvachua.Ferrando.1',
#   'B.M.Shurygin.1',
#   'B.Mura.1',
#   'B.N.Guskov.1',
#   'B.Nicquevert.1',
#   'Bobby.Samir.Acharya.1',
#   'Bo.Li.1',
#   'Bo.Liu.2',
#   'B.Osculati.1',
#   'B.Pan.3',
#   'B.Parida.1',
#   'B.Pavlov.1',
#   'B.Penning.1',
#   'B.Philipps.1',
#   'B.Pinto.1',
#   'B.P.Kersevan.1',
#   'B.Pollack.1',
#   'B.P.Padley.1',
#   'Braden.Keim.Abbott.1',
#   'B.Rahbaran.2',
#   'B.R.Drell.1',
#   'B.Reitz.1',
#   'B.Resende.1',
#   'Britt.Holbrook.1',
#   'B.R.Ko.1',
#   'B.Roland.1',
#   'B.Rutherford.1',
#   'B.R.Voicu.1',
#   'B.Safarzadeh.1',
#   'B.Sarrazin.1',
#   'B.Schneider.1',
#   'B.Scott.1',
#   'B.Scurlock.1',
#   'B.Sellden.1',
#   'B.Simmons.1',
#   'B.Smart.1',
#   'B.Snook.1',
#   'B.Sopko.1',
#   'B.Spaan.1',
#   'B.Spurlock.1',
#   'B.Stieger.1',
#   'B.Stugu.1',
#   'B.Tali.1',
#   'B.T.Carlson.1',
#   'B.T.Huffman.1',
#   'B.T.Martin.1',
#   'B.T.Meadows.1',
#   'B.Toggerson.1',
#   'B.Trocme.1',
#   'B.T.Winter.1',
#   'Bugra.Bilin.1',
#   'B.Ujvari.1',
#   'B.Vachon.1',
#   'B.V.Grinyov.2',
#   'B.Vlahovic.1',
#   'B.V.Morozov.1',
#   'B.Walsh.2',
#   'B.Waugh.1',
#   'B.W.Drummond.1',
#   'B.Weinert.1',
#   'B.Wittmer.1',
#   'B.W.Kennedy.1',
#   'B.Wojtsekhowski.1',
#   'B.Wosiek.1',
#   'B.Wrona.1',
#   'B.Wynne.1',
#   'B.Wyslouch.1',
#   'B.Zhou.1',
#   'B.Zhu.2',
#   'C.A.Bernardes.1',
#   'C.A.Blocker.1',
#   'C.A.Chavez.Barajas.1',
#   'C.A.George.1',
#   'C.A.Hagmann.1',
#   'C.A.Heusch.1',
#   'Caitlin.M.Malone.1',
#   ...],
#  'references': [{'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/12291'},
#    'reference': {'authors': [{'full_name': 'Englert, F.'},
#      {'full_name': 'Brout, R.'}],
#     'label': '1',
#     'publication_info': {'journal_title': 'Phys.Rev.Lett.',
#      'journal_volume': '13',
#      'page_end': '323',
#      'page_start': '321',
#      'year': 1964}}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/40440'},
#    'reference': {'authors': [{'full_name': 'Higgs, P.W.'}],
#     'label': '2',
#     'publication_info': {'journal_title': 'Phys.Lett.',
#      'journal_volume': '12',
#      'page_end': '133',
#      'page_start': '132',
#      'year': 1964}}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/11883'},
#    'reference': {'authors': [{'full_name': 'Higgs, P.W.'}],
#     'label': '3',
#     'publication_info': {'journal_title': 'Phys.Rev.Lett.',
#      'journal_volume': '13',
#      'page_end': '509',
#      'page_start': '508',
#      'year': 1964}}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/12292'},
#    'reference': {'authors': [{'full_name': 'Guralnik, G.S.'},
#      {'full_name': 'Hagen, C.R.'},
#      {'full_name': 'Kibble, T.W.B.'}],
#     'label': '4',
#     'publication_info': {'journal_title': 'Phys.Rev.Lett.',
#      'journal_volume': '13',
#      'page_end': '587',
#      'page_start': '585',
#      'year': 1964}}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/50073'},
#    'reference': {'authors': [{'full_name': 'Higgs, P.W.'}],
#     'label': '5',
#     'publication_info': {'journal_title': 'Phys.Rev.',
#      'journal_volume': '145',
#      'page_end': '1163',
#      'page_start': '1156',
#      'year': 1966}}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/1124337'},
#    'reference': {'arxiv_eprint': '1207.7214',
#     'collaborations': ['ATLAS Collaboration'],
#     'label': '6',
#     'publication_info': {'journal_title': 'Phys.Lett.B',
#      'journal_volume': '716',
#      'page_end': '29',
#      'page_start': '1',
#      'year': 2012}}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/1124338'},
#    'reference': {'arxiv_eprint': '1207.7235',
#     'collaborations': ['CMS Collaboration'],
#     'label': '7',
#     'publication_info': {'journal_title': 'Phys.Lett.B',
#      'journal_volume': '716',
#      'page_end': '61',
#      'page_start': '30',
#      'year': 2012}}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/1304454'},
#    'reference': {'arxiv_eprint': '1407.0558',
#     'collaborations': ['CMS Collaboration'],
#     'label': '8'}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/1300650'},
#    'reference': {'arxiv_eprint': '1406.3827',
#     'collaborations': ['ATLAS Collaboration'],
#     'label': '9',
#     'publication_info': {'artid': '052004',
#      'journal_title': 'Phys.Rev.D',
#      'journal_volume': '90',
#      'year': 2014}}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/1126428'},
#    'reference': {'authors': [{'full_name': 'Beringer, J.'}],
#     'collaborations': ['Particle Data Group'],
#     'label': '10',
#     'misc': ['p. 157'],
#     'publication_info': {'artid': '010001',
#      'journal_title': 'Phys.Rev.D',
#      'journal_volume': '86',
#      'year': 2012}}},
#   {'reference': {'authors': [{'full_name': 'Scheck, F.'}],
#     'imprint': {'publisher': 'Springer'},
#     'label': '11',
#     'misc': ['Electroweak and Strong Interactions. Phenomenology, Concepts, Models, 3rd ed -Verlag, Berlin, Heidelberg,, 2012), p. 232'],
#     'publication_info': {'year': 1996}}},
#   {'reference': {'authors': [{'full_name': 'Schwartz, M.D.'}],
#     'label': '12',
#     'misc': ['Quantum Field Theory and the Standard Model, (Cambridge University Press, Cambridge, UK), p. 161'],
#     'publication_info': {'year': 2014}}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/1243422'},
#    'reference': {'arxiv_eprint': '1307.4935',
#     'authors': [{'full_name': 'Caola, F.'}, {'full_name': 'Melnikov, K.'}],
#     'label': '13',
#     'publication_info': {'artid': '054024',
#      'journal_title': 'Phys.Rev.D',
#      'journal_volume': '88',
#      'year': 2013}}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/820758'},
#    'reference': {'arxiv_eprint': '0905.2928',
#     'authors': [{'full_name': 'Dhar, A.'},
#      {'full_name': 'Mandal, G.'},
#      {'full_name': 'Wadia, S.R.'}],
#     'label': '14',
#     'misc': ['(2009)'],
#     'publication_info': {'artid': '105018',
#      'journal_title': 'Phys.Rev.D',
#      'journal_volume': '80',
#      'year': 2010}}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/1026'},
#    'reference': {'authors': [{'full_name': 'Gross, D.J.'},
#      {'full_name': 'Neveu, A.'}],
#     'label': '15',
#     'publication_info': {'artid': '3235',
#      'journal_title': 'Phys.Rev.D',
#      'journal_volume': '10',
#      'page_start': '3235',
#      'year': 1974}}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/4327'},
#    'reference': {'authors': [{'full_name': 'Nambu, Y.'},
#      {'full_name': 'Jona-Lasinio, G.'}],
#     'label': '16',
#     'publication_info': {'artid': '345',
#      'journal_title': 'Phys.Rev.',
#      'journal_volume': '122',
#      'page_start': '345',
#      'year': 1961}}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/1239042'},
#    'reference': {'arxiv_eprint': '1303.5283',
#     'authors': [{'full_name': 'Trinhammer, O.L.'}],
#     'label': '17',
#     'misc': ['Eur'],
#     'publication_info': {'artid': '42002',
#      'journal_title': 'Phys.Lett.',
#      'journal_volume': '102',
#      'year': 2013}}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/1218032'},
#    'reference': {'arxiv_eprint': '1302.1779',
#     'authors': [{'full_name': 'Trinhammer, O.L.'}],
#     'label': '18'}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/1336'},
#    'reference': {'authors': [{'full_name': 'Kogut, J.B.'},
#      {'full_name': 'Susskind, L.'}],
#     'label': '19',
#     'publication_info': {'artid': '395',
#      'journal_title': 'Phys.Rev.D',
#      'journal_volume': '11',
#      'page_start': '395',
#      'year': 1975}}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/158837'},
#    'reference': {'authors': [{'full_name': 'Manton, N.S.'}],
#     'label': '20',
#     'publication_info': {'journal_title': 'Phys.Lett.B',
#      'journal_volume': '96',
#      'page_end': '330',
#      'page_start': '328',
#      'year': 1980}}},
#   {'reference': {'authors': [{'full_name': 'Trinhammer, O.'}],
#     'label': '21',
#     'misc': ['Phys. Lett. B 129(3,4) 234-238'],
#     'publication_info': {'year': 1983}}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/1126428'},
#    'reference': {'authors': [{'full_name': 'Beringer, J.'}],
#     'collaborations': ['Particle Data Group'],
#     'label': '22',
#     'misc': ['p. 131'],
#     'publication_info': {'artid': '010001',
#      'journal_title': 'Phys.Rev.D',
#      'journal_volume': '86',
#      'year': 2012}}},
#   {'reference': {'authors': [{'full_name': 'Weinberg, S.'}],
#     'label': '23',
#     'misc': ['The Quantum Theory of Fields - Modern Applications, Vol. II, (Cambridge University Press/2012), p. 186'],
#     'publication_info': {'year': 1995}}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/659463'},
#    'reference': {'authors': [{'full_name': 'Bohr, H.'},
#      {'full_name': 'Providencia, C.'},
#      {'full_name': 'da Providencia, J.'}],
#     'label': '24',
#     'publication_info': {'artid': '055203',
#      'journal_title': 'Phys.Rev.C',
#      'journal_volume': '71',
#      'year': 2005}}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/441397'},
#    'reference': {'authors': [{'full_name': 'Diakonov, D.'},
#      {'full_name': 'Petrov, V.'},
#      {'full_name': 'Polyakov, M.'}],
#     'label': '25',
#     'misc': ['ArXiv:9703373v2 [hep-ph]'],
#     'publication_info': {'journal_title': 'Z.Phys.A',
#      'journal_volume': '359',
#      'page_end': '312',
#      'page_start': '305',
#      'year': 1997}}},
#   {'reference': {'authors': [{'full_name': 'Heisenberg, W.'}],
#     'label': '26',
#     'misc': ['Ann. d. Phys. (5) 32 20-33'],
#     'publication_info': {'year': 1938}}},
#   {'reference': {'authors': [{'full_name': 'Landau, L.D.'},
#      {'full_name': 'Lifshitz, E.M.'}],
#     'imprint': {'publisher': 'Elsevier'},
#     'label': '27',
#     'misc': ['The Classical Theory of Fields, Course of Theoretical h ed Butterworth-Heinemann, Oxford), p. 97'],
#     'publication_info': {'artid': '4',
#      'journal_title': 'Physics',
#      'journal_volume': '2',
#      'page_start': '4',
#      'year': 2005}}},
#   {'reference': {'label': '28', 'misc': ['See ref.22 p. 107']}},
#   {'reference': {'label': '29', 'misc': ['See ref.22 p. 137!']}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/89145'},
#    'reference': {'authors': [{'full_name': 'Wilson, K.G.'}],
#     'label': '30',
#     'publication_info': {'artid': '2445',
#      'journal_title': 'Phys.Rev.D',
#      'journal_volume': '10',
#      'page_start': '2445',
#      'year': 1974}}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/152563'},
#    'reference': {'authors': [{'full_name': 'Wadia, S.R.'}],
#     'label': '31',
#     'publication_info': {'journal_title': 'Phys.Lett.B',
#      'journal_volume': '93',
#      'page_end': '410',
#      'page_start': '403',
#      'year': 1980}}},
#   {'reference': {'authors': [{'full_name': 'Jacobsen, H.P.'}],
#     'label': '32',
#     'misc': ['Department of Mathematics, University of Copenhagen, private communication approx'],
#     'publication_info': {'year': 1997}}},
#   {'reference': {'label': '33', 'misc': ['See ref.22 pp. 78-83']}},
#   {'reference': {'authors': [{'full_name': 'Particle, G. Höhler in'}],
#     'label': '34',
#     'misc': ['Data Group, Phys. Lett. B239, , p. VIII.10'],
#     'publication_info': {'year': 1990}}},
#   {'reference': {'authors': [{'full_name': 'Trinhammer, O.L.'},
#      {'full_name': 'Olafsson, G.'}],
#     'label': '35',
#     'misc': ['arXiv:9901002v2 [math-ph]']}},
#   {'reference': {'authors': [{'full_name': 'Weyl, H.'}],
#     'label': '36',
#     'misc': ['The Classical Groups - Their Invariants and Representations, 2nd ed. (Princeton University Press), p. 197'],
#     'publication_info': {'year': 1997}}},
#   {'reference': {'authors': [{'full_name': 'Schiff, L.I.'}],
#     'imprint': {'publisher': 'McGraw-Hill'},
#     'label': '37',
#     'misc': ['Quantum Mechanics, 3rd. ed /1968), p. 210'],
#     'publication_info': {'year': 1955}}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/8640'},
#    'reference': {'authors': [{'full_name': 'Okubo, S.'}],
#     'label': '38',
#     'misc': ['Note on Unitary Symmetry in Strong Interactions'],
#     'publication_info': {'journal_title': 'Prog.Theor.Phys.',
#      'journal_volume': '27',
#      'page_end': '966',
#      'page_start': '949',
#      'year': 1962}}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/2477'},
#    'reference': {'authors': [{'full_name': 'Gell-Mann, M.'}],
#     'label': '39',
#     'misc': ['Symmetries of Baryons and Mesons'],
#     'publication_info': {'journal_title': 'Phys.Rev.',
#      'journal_volume': '125',
#      'page_end': '1084',
#      'page_start': '1067',
#      'year': 1962}}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/9149'},
#    'reference': {'authors': [{'full_name': "Ne'eman, Y."}],
#     'label': '40',
#     'misc': ['Derivation of Strong Interactions from a Gauge Invariance'],
#     'publication_info': {'journal_title': 'Nucl.Phys.',
#      'journal_volume': '26',
#      'page_end': '229',
#      'page_start': '222',
#      'year': 1962}}},
#   {'reference': {'authors': [{'full_name': 'Gasiorowicz, S.'}],
#     'imprint': {'publisher': 'Wiley'},
#     'label': '41',
#     'misc': ['Elementary Particle Physics and Sons, New York,), p.287'],
#     'publication_info': {'year': 1966}}},
#   {'reference': {'authors': [{'full_name': 'Nielsen, H. Bruun'}],
#     'label': '42',
#     'misc': ['Technical University of Denmark, (suggested in private communications,)'],
#     'publication_info': {'year': 1997}}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/60984'},
#    'reference': {'authors': [{'full_name': 'Dowker, J.S.'}],
#     'label': '43',
#     'publication_info': {'journal_title': 'Annals Phys.',
#      'journal_volume': '62',
#      'page_end': '382',
#      'page_start': '361',
#      'year': 1971}}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/47474'},
#    'reference': {'authors': [{'full_name': 'Slater, J.C.'}],
#     'label': '44',
#     'publication_info': {'artid': '1293',
#      'journal_title': 'Phys.Rev.',
#      'journal_volume': '34',
#      'page_start': '1293',
#      'year': 1929}}},
#   {'reference': {'authors': [{'full_name': 'Berestetskii, V.B.'},
#      {'full_name': 'Lifshitz, E.M.'},
#      {'full_name': 'Pitaevskii, L.P.'}],
#     'imprint': {'publisher': 'Elsevier'},
#     'label': '45',
#     'misc': ['Quantum Electrodynamics - Landau and Lifshitz Course of Theoretical d edition (/2004), p. 603'],
#     'publication_info': {'artid': '2',
#      'journal_title': 'Physics',
#      'journal_volume': '4',
#      'page_start': '2',
#      'year': 1982}}},
#   {'reference': {'label': '46', 'misc': ['See ref.22 p. 136']}},
#   {'reference': {'label': '47', 'misc': ['See ref.23 p. 158 and p. 126']}},
#   {'reference': {'label': '48',
#     'misc': ['Programmes available at ~trinham/BaryonLieProgrammes/'],
#     'urls': [{'value': 'https://dcwww.fysik.dtu.dk/'}]}},
#   {'reference': {'authors': [{'full_name': 'Ashcroft, N.W.'},
#      {'full_name': 'Mermin, N.D.'}],
#     'label': '49',
#     'misc': ['Solid State Physics, (Holt, Rinehart and Winston, New York), p. 160'],
#     'publication_info': {'year': 1976}}},
#   {'reference': {'label': '50', 'misc': ['See ref.22 p. 205']}},
#   {'reference': {'label': '51', 'misc': ['See ref.22 p. 79']}},
#   {'reference': {'authors': [{'full_name': 'Holm, P.'}],
#     'label': '52',
#     'misc': ['Rungsted Gymnasium, Denmark, private communication'],
#     'publication_info': {'year': 1993}}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/811001'},
#    'reference': {'authors': [{'full_name': 'Klempt, E.'},
#      {'full_name': 'Richard, J.M.'}],
#     'label': '53',
#     'publication_info': {'artid': '1095',
#      'journal_title': 'Rev.Mod.Phys.',
#      'journal_volume': '82',
#      'page_start': '1095',
#      'year': 2010}}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/201523'},
#    'reference': {'authors': [{'full_name': 'Aleev, A.N.'}],
#     'label': '54',
#     'publication_info': {'journal_title': 'Z.Phys.C',
#      'journal_volume': '25',
#      'page_end': '212',
#      'page_start': '205',
#      'year': 1984}}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/1323450'},
#    'reference': {'arxiv_eprint': '1410.6418',
#     'authors': [{'full_name': 'Alekseev, I.G.'}],
#     'label': '55',
#     'misc': ['EPECUR Collaboration and GW INS Data Analysis Center']}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/659852'},
#    'reference': {'authors': [{'full_name': 'Zhu, L.Y.'}],
#     'label': '56',
#     'publication_info': {'artid': '044603',
#      'journal_title': 'Phys.Rev.C',
#      'journal_volume': '71',
#      'year': 2005}}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/819092'},
#    'reference': {'authors': [{'full_name': 'Aubert, B.'}],
#     'label': '57',
#     'misc': ['BABAR Collaboration'],
#     'publication_info': {'artid': '112009',
#      'journal_title': 'Phys.Rev.D',
#      'journal_volume': '79',
#      'year': 2009}}},
#   {'reference': {'authors': [{'full_name': 'Cornwell, J.F.'}],
#     'imprint': {'publisher': 'Academic'},
#     'label': '58',
#     'misc': ['Group Theory in Physics, Vol. 2 Press, Amsterdam/2004), Appendix J'],
#     'publication_info': {'year': 1984}}},
#   {'reference': {'authors': [{'full_name': 'Nielsen, H. Bech'}],
#     'label': '59',
#     'misc': ['Niels Bohr Institute, Copenhagen, private communication 199x']}},
#   {'reference': {'authors': [{'full_name': 'Guillemin, V.'},
#      {'full_name': 'Pollack, A.'}],
#     'imprint': {'publisher': 'Prentice-Hall'},
#     'label': '60',
#     'misc': ['Differential Topology New Jersey, USA), p. 163'],
#     'publication_info': {'year': 1974}}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/443682'},
#    'reference': {'authors': [{'full_name': 'Brodsky, S.J.'},
#      {'full_name': 'Pauli, H.-C.'},
#      {'full_name': 'Pincky, S.S.'}],
#     'label': '61',
#     'misc': ['p. 312'],
#     'publication_info': {'journal_title': 'Phys.Rept.',
#      'journal_volume': '301',
#      'page_end': '486',
#      'page_start': '299',
#      'year': 1998}}},
#   {'reference': {'authors': [{'full_name': 'Eidelman, S.'}],
#     'collaborations': ['Particle Data Group'],
#     'label': '62',
#     'misc': ['Phys. Lett. B 592'],
#     'publication_info': {'year': 2004}}},
#   {'reference': {'authors': [{'full_name': 'Donoghue, J.F.'},
#      {'full_name': 'Golowich, E.'},
#      {'full_name': 'Holstein, B.R.'}],
#     'label': '63',
#     'misc': ['(Cambridge University Press, Cambridge/1996), p. 16'],
#     'publication_info': {'year': 1992},
#     'title': {'title': 'Dynamics of the standard model'}}},
#   {'reference': {'authors': [{'full_name': 'Griffiths, D.'}],
#     'imprint': {'publisher': 'Wiley-VCH'},
#     'label': '64',
#     'misc': ['2nd ed Weinheim, Germany/2012) p. 403'],
#     'publication_info': {'year': 2008},
#     'title': {'title': 'Introduction to elementary particles'}}},
#   {'reference': {'label': '65', 'misc': ['See ref.64 p. 355']}},
#   {'reference': {'label': '66', 'misc': ['See ref.47 p. 303']}},
#   {'reference': {'label': '67', 'misc': ['See ref.64 p. 381']}},
#   {'reference': {'authors': [{'full_name': 'Aitchison, I.J.R.'},
#      {'full_name': 'Hey, A.J.G.'}],
#     'label': '68',
#     'misc': ['Gauge Theories in Particle Physics - A Practical Introduction 4th ed., Vol. 2, (CRC Press, Boca Raton, London, New York), p. 380'],
#     'publication_info': {'year': 2013}}},
#   {'reference': {'label': '69', 'misc': ['See ref.58 pp. 766, 786, 799']}},
#   {'reference': {'label': '70', 'misc': ['See ref.23 pp. 308']}},
#   {'reference': {'authors': [{'full_name': 'Lancaster, T.'},
#      {'full_name': 'Blundell, S.J.'}],
#     'label': '71',
#     'misc': ['Quantum Field Theory for the Gifted Amateur, (Oxford University Press, Oxford, United Kingdom,), p. 437'],
#     'publication_info': {'year': 2014}}},
#   {'reference': {'label': '72', 'misc': ['See ref.23 p. 310']}},
#   {'reference': {'authors': [{'full_name': 'Amtrup, T.'}],
#     'label': '73',
#     'misc': ['Two integral presumptions, LMFK-bladet no. 4, April. Available at ~trinham/BaryonLieProgrammes/'],
#     'publication_info': {'year': 1998},
#     'urls': [{'value': 'https://dcwww.fysik.dtu.dk/'}]}},
#   {'reference': {'label': '74', 'misc': ['See ref.68 p. 381']}},
#   {'reference': {'label': '75', 'misc': ['See ref.23 p. 307, p. 309']}},
#   {'reference': {'authors': [{'full_name': 'Taylor, J.R.'}],
#     'label': '76',
#     'misc': ['An Introduction to Error Analysis, 2nd ed., (University Science Books, California, USA,/1997), pp. 175'],
#     'publication_info': {'year': 1982}}},
#   {'reference': {'label': '77', 'misc': ['See ref.22 pp. 157, 852']}},
#   {'reference': {'label': '78', 'misc': ['See ref.68 p. 235']}},
#   {'reference': {'label': '79', 'misc': ['See ref.10 pp. 157, 852']}},
#   {'reference': {'authors': [{'full_name': 'Halzen, F.'},
#      {'full_name': 'Martin, A.J.'}],
#     'imprint': {'publisher': 'Wiley'},
#     'label': '80',
#     'misc': ['(J and Sons, New York, Chichester, Brisbane, Toronto, Singapore,), p. 282'],
#     'publication_info': {'year': 1984},
#     'title': {'title': 'QUARKS AND LEPTONS: AN INTRODUCTORY COURSE IN MODERN PARTICLE PHYSICS'}}},
#   {'reference': {'label': '81', 'misc': ['See ref.23 p. 185']}},
#   {'reference': {'authors': [{'full_name': 'Jegerlehner, F.'}],
#     'label': '82',
#     'misc': ['ArXiv:hep-ph/960684v1'],
#     'publication_info': {'artid': '131141',
#      'journal_title': 'Nucl.Phys.B Proc.Suppl.',
#      'journal_volume': '51',
#      'year': 1996}}},
#   {'reference': {'authors': [{'full_name': 'Olive, K.A.'}],
#     'label': '83',
#     'misc': ['(Particle Data Group) 9): 090001. p.33'],
#     'publication_info': {'artid': '38',
#      'journal_title': 'Chin.Phys.C',
#      'journal_volume': '2014',
#      'page_start': '38'}}},
#   {'reference': {'label': '84', 'misc': ['See ref.23 p. 126']}},
#   {'reference': {'label': '85', 'misc': ['See ref.83 p. 140']}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/1117458'},
#    'reference': {'arxiv_eprint': '1206.1284',
#     'authors': [{'full_name': 'Baikov, P.A.'}],
#     'label': '86',
#     'publication_info': {'artid': '017',
#      'journal_title': 'JHEP',
#      'journal_volume': '07',
#      'page_start': '017',
#      'year': 2012}}},
#   {'reference': {'label': '87', 'misc': ['See ref.83 p. 109']}},
#   {'curated_relation': False,
#    'record': {'ref': 'https://inspirehep.net/api/literature/1335811'},
#    'reference': {'arxiv_eprint': '1412.8662',
#     'collaborations': ['CMS Collaboration'],
#     'label': '88'}},
#   {'reference': {'authors': [{'full_name': 'J, Actually'}],
#     'label': '89',
#     'misc': ['≡ √ J2 = √ D∗D, and D = 3 i<j(eiθi - eiθj ) is Weyl’s Van de Monde determinant36']}}],
#  'titles': [{'source': 'arXiv',
#    'title': 'The Higgs mass derived from the U(3) Lie group'}]}

# %%
journal_info_keys[67004]
# Out:
# dict_keys(['year', 'parent_record', 'conference_record', 'journal_volume', 'page_start', 'journal_title', 'page_end', 'cnum'])

# %% [markdown]
# So, apparently conference recods/papers appear with the keys `cnum` and articles published in journals have the `journal_title` key.
#
# NOTE: I decide then to only keep the jornal name IF the paper is published on a journal. Those that are conference papers/conference records are discarded. I do so because we are interested in articles that are published in journals.

# %%
def extract_journal(metadata_dict: dict):
    if ('publication_info' in metadata_dict.keys()): 
         return list(np.unique([publication_info['journal_title'] for publication_info in metadata_dict['publication_info'] if ('journal_title' in publication_info.keys())]))
    else: 
        return []

journal_name = df['metadata'].map( 
    extract_journal
)

# %% [markdown]
# ...and finally assign to column in dataframe. Notice that the result is a column in which each row contains a list with the name of the journals.

# %%
df['journal'] = journal_name

# %% [markdown]
# ##### Category

# %% [markdown]
# Extract INSPIRE category of each document

# %%
def extract_category(metadata_dict: dict):
    if ('inspire_categories' in metadata_dict.keys()): 
         return [category['term'] for category in metadata_dict['inspire_categories']]
    else: 
        return []

categories = df['metadata'].map( 
    extract_category
)

# %%
categories.sample(10)
# Out:
# 55952                                    [Instrumentation]
# 22233                                     [Experiment-HEP]
# 16914      [Experiment-HEP, Instrumentation, Astrophysics]
# 61787                                     [Experiment-HEP]
# 65677                                    [Instrumentation]
# 65332    [Phenomenology-HEP, Theory-HEP, Phenomenology-...
# 24995                                       [Astrophysics]
# 55057                         [Computing, Instrumentation]
# 49363                         [Phenomenology-HEP, Lattice]
# 10443                           [Phenomenology-HEP, Other]
# Name: metadata, dtype: object

# %%
df['categories'] = categories

# %% [markdown]
# ##### Date

# %% [markdown]
# To normalize the date (dates are in different formats) transform the `created` colum into a datetime object and then back to string

# %%
df['created'] = pd.to_datetime(df['created']).map(lambda date: date.strftime("%Y-%m-%d"))

# %% [markdown]
# ---

# %% [markdown]
# Lets look at the end result of data cleaning and preparation

# %%
df.sample(10)
# Out:
#            _id                                      citations_ids     created  \
# 53113  1444354                                                 []  2016-04-07
# 45857   809498                                                 []  2009-07-03
# 37942  1328513                                                 []  2014-11-18
# 13620  1294485                                                 []  2014-05-06
# 26875  1692797                                                 []  2018-09-06
# 19765  1514166                                                 []  2017-02-20
# 42964  1469256                                                 []  2016-06-15
# 28645  1611681  [1749017, 1768528, 1726238, 1664648, 1713226, ...  2017-07-27
# 53865   701785                                                 []  2006-01-06
# 6015   1834020                                                 []  2020-12-01
#
#                                                    links  \
# 53113  {'bibtex': 'https://inspirehep.net/api/literat...
# 45857  {'citations': 'https://inspirehep.net/api/lite...
# 37942  {'citations': 'https://inspirehep.net/api/lite...
# 13620  {'citations': 'https://inspirehep.net/api/lite...
# 26875  {'bibtex': 'https://inspirehep.net/api/literat...
# 19765  {'citations': 'https://inspirehep.net/api/lite...
# 42964  {'bibtex': 'https://inspirehep.net/api/literat...
# 28645  {'bibtex': 'https://inspirehep.net/api/literat...
# 53865  {'citations': 'https://inspirehep.net/api/lite...
# 6015   {'citations': 'https://inspirehep.net/api/lite...
#
#                                                 metadata  \
# 53113  {'citation_count_without_self_citations': 0, '...
# 45857  {'citation_count_without_self_citations': 2, '...
# 37942  {'citation_count_without_self_citations': 79, ...
# 13620  {'citation_count_without_self_citations': 0, '...
# 26875  {'citation_count_without_self_citations': 0, '...
# 19765  {'citation_count_without_self_citations': 6, '...
# 42964  {'citation_count_without_self_citations': 11, ...
# 28645  {'citation_count_without_self_citations': 6, '...
# 53865  {'citation_count_without_self_citations': 3, '...
# 6015   {'citation_count_without_self_citations': 0, '...
#
#                                 updated  \
# 53113  2021-01-07T03:57:30.683080+00:00
# 45857  2021-01-07T08:55:16.890119+00:00
# 37942  2021-01-09T11:39:19.440685+00:00
# 13620  2020-11-26T23:01:01.226993+00:00
# 26875  2021-01-07T02:10:06.642220+00:00
# 19765  2020-11-27T01:31:00.332102+00:00
# 42964  2021-01-06T18:42:29.553351+00:00
# 28645  2021-01-07T17:12:28.405614+00:00
# 53865  2020-11-26T18:01:06.991410+00:00
# 6015   2021-01-07T02:45:02.644891+00:00
#
#                                                    title       document_type  \
# 53113  Inclusive production of $H\rightarrow b\bar{b}...           [article]
# 45857  Study of ATLAS sensitivity to asymmetries in s...            [thesis]
# 37942     Introduction to parton-shower event generators  [conference paper]
# 13620                      Quarkonium results at the LHC  [conference paper]
# 26875  Studying flavor-changing neutral tqZ couplings...           [article]
# 19765         The Full Event Interpretation for Belle II            [thesis]
# 42964  $h\to\mu\tau$ and muon g-2 in the alignment li...           [article]
# 28645  Observation of $D^0$ meson decays to $\pi^+\pi...           [article]
# 53865  Recent advancements in the development of radi...  [conference paper]
# 6015              Collider constraints on dark mediators           [article]
#
#                      journal                              categories
# 53113                  [EPL]                     [Phenomenology-HEP]
# 45857                     []                        [Experiment-HEP]
# 37942                     []                     [Phenomenology-HEP]
# 13620          [Nuovo Cim.C]                        [Experiment-HEP]
# 26875      [Mod.Phys.Lett.A]  [Phenomenology-HEP, Phenomenology-HEP]
# 19765                     []                        [Experiment-HEP]
# 42964          [Nucl.Phys.B]                     [Phenomenology-HEP]
# 28645       [Phys.Rev.Lett.]                        [Experiment-HEP]
# 53865  [Nucl.Instrum.Meth.A]                       [Instrumentation]
# 6015                      []                     [Phenomenology-HEP]

# %% [markdown]
# ## Build Network

# %% [markdown]
# Now that the data is ready we build the network.

# %%
G = nx.DiGraph()

# %% [markdown]
# ### Nodes

# %% [markdown]
# First lets drop the unnecessary colums

# %%
df = df.drop(columns=['links','metadata','updated'])

# %% [markdown]
# and then build the nodes: a list of tuples where each element is a node. Each tuple (a.k.a. node) contains on its first element the node `id` and the second element is a dict with additional data.
#
# To acchieve this lets get the `_id` column and convert the rest of the columns into a list of dicts. After, they can be zipped into the required list.

# %%
nodes = zip(df['_id'], df.drop(columns=['_id']).to_dict('records'))

# %% [markdown]
# (notice `zip` returns an iterable and not a list)

# %% [markdown]
# Add nodes to the network

# %%
G.add_nodes_from(nodes)

# %% [markdown]
# and export them to a file as well

# %%
df.to_csv('nodes.csv', index=False)

# %% [markdown]
# ###  Edges

# %% [markdown]
# Now we build the edges

# %%
edges = []
#iterate over dataframe rows (aka each article)
for idx in tqdm(range(df.shape[0])):
    # and then over every citation
    for citation_id in df.iloc[idx]['citations_ids']:
        edge = { 
            'article_id': df.iloc[idx]['_id'],
            'article_title': df.iloc[idx]['title'],
            'citation_id': citation_id,
            'citation_title': df[df['_id'] == str(citation_id)]['title'].values[0]    # find the citation title on the dataframe
        }
        edges.append(edge)
        
        # add edge to the networkx graph
        G.add_edge(edge['citation_id'], edge['article_id'], 
                   citation_title=edge['citation_title'], 
                   article_title=edge['article_title'] 
                  )
        
edges_df = pd.DataFrame(edges)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=67031.0), HTML(value='')))

# %%
edges_df.sample(10)
# Out:
#        article_id                                      article_title  \
# 9860      1749379  Search for supersymmetry in proton-proton coll...
# 90225     1093733  Measurement of the azimuthal anisotropy for ch...
# 109986    1082456  Measurement of the charge asymmetry in top-qua...
# 7094      1286320  First combination of Tevatron and LHC measurem...
# 188880    1426744  Search for electroweak production of charginos...
# 36241     1696607  Combined measurements of Higgs boson couplings...
# 37803     1691634  Observation of $H \rightarrow b\bar{b}$ decays...
# 32374     1219960  Improved luminosity determination in pp collis...
# 212266    1394580  Transverse momentum dependence of D-meson prod...
# 36327     1696607  Combined measurements of Higgs boson couplings...
#
#         citation_id                                     citation_title
# 9860        1757727                                        Axiogenesis
# 90225       1114983  Study on initial geometry fluctuations via par...
# 109986      1207587  Data driving the top quark forward--backward a...
# 7094        1286587                      Is Higgs inflation ruled out?
# 188880      1464830  Electroweakino pair production at the LHC: NLO...
# 36241       1735333  Search for lepton flavour violating decays of ...
# 37803       1815813  Evidence for Higgs boson decay to a pair of muons
# 32374       1254228  Search for dark matter in events with a hadron...
# 212266      1490655  Effective field theory approach to open heavy ...
# 36327       1809953  Measurement of the properties of Higgs boson p...

# %%
edges_df.to_csv('edges.csv', index=False)

# %% [markdown]
# #####  Export the data to gexf and json

# %%
from networkx.readwrite import json_graph
from bson import json_util

# %%
data_json = json_graph.node_link_data(G)
with open('network.json', 'w') as outfile:
    json.dump(data_json,outfile, default=json_util.default)

# %%
nx.write_gexf(G, "network.gexf")
